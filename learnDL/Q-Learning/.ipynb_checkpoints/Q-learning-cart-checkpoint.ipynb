# %% [markdown]
# # Deep Q-learning
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import gym
import tensorflow as tf
import numpy as np

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %%
# Create the Cart-Pole game environment
env = gym.make('CartPole-v0')
# Out:
# [2017-06-29 00:56:22,974] Making new env: CartPole-v0

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
env.reset()
rewards = []
for _ in range(100):
    env.render()
    state, reward, done, info = env.step(env.action_space.sample()) # take a random action
    rewards.append(reward)
    if done:
        rewards = []
        env.reset()

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
print(rewards[-20:])
# Out:
# []

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
class QNetwork:
    def __init__(self, learning_rate=0.01, state_size=4, 
                 action_size=2, hidden_size=10, 
                 name='QNetwork'):
        # state inputs to the Q-network
        with tf.variable_scope(name):
            self.inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs')
            
            # One hot encode the actions to later choose the Q-value for the action
            self.actions_ = tf.placeholder(tf.int32, [None], name='actions')
            one_hot_actions = tf.one_hot(self.actions_, action_size)
            
            # Target Q values for training
            self.targetQs_ = tf.placeholder(tf.float32, [None], name='target')
            
            # ReLU hidden layers
            self.fc1 = tf.contrib.layers.fully_connected(self.inputs_, hidden_size)
            self.fc2 = tf.contrib.layers.fully_connected(self.fc1, hidden_size)

            # Linear output layer
            self.output = tf.contrib.layers.fully_connected(self.fc2, action_size, 
                                                            activation_fn=None)
            
            ### Train with loss (targetQ - Q)^2
            # output has length 2, for two actions. This next line chooses
            # one value from output (per row) according to the one-hot encoded actions.
            self.Q = tf.reduce_sum(tf.multiply(self.output, one_hot_actions), axis=1)
            
            self.loss = tf.reduce_mean(tf.square(self.targetQs_ - self.Q))
            self.opt = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    
    def add(self, experience):
        self.buffer.append(experience)
            
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
train_episodes = 1000          # max number of episodes to learn from
max_steps = 200                # max steps in an episode
gamma = 0.99                   # future reward discount

# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 20                # experience mini-batch size
pretrain_length = batch_size   # number experiences to pretrain the memory

# %%
tf.reset_default_graph()
mainQN = QNetwork(name='main', hidden_size=hidden_size, learning_rate=learning_rate)

# %% [markdown]
# ## Populate the experience memory
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
# Initialize the simulation
env.reset()
# Take one random step to get the pole and cart moving
state, reward, done, _ = env.step(env.action_space.sample())

memory = Memory(max_size=memory_size)

# Make a bunch of random actions and store the experiences
for ii in range(pretrain_length):
    # Uncomment the line below to watch the simulation
    # env.render()

    # Make a random action
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)

    if done:
        # The simulation fails so no next state
        next_state = np.zeros(state.shape)
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        
        # Start new episode
        env.reset()
        # Take one random step to get the pole and cart moving
        state, reward, done, _ = env.step(env.action_space.sample())
    else:
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        state = next_state

# %% [markdown]
# ## Training
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Now train with experiences
saver = tf.train.Saver()
rewards_list = []
with tf.Session() as sess:
    # Initialize variables
    sess.run(tf.global_variables_initializer())
    
    step = 0
    for ep in range(1, train_episodes):
        total_reward = 0
        t = 0
        while t < max_steps:
            step += 1
            # Uncomment this next line to watch the training
            # env.render() 
            
            # Explore or Exploit
            explore_p = explore_stop + (explore_start - explore_stop)*np.exp(-decay_rate*step) 
            if explore_p > np.random.rand():
                # Make a random action
                action = env.action_space.sample()
            else:
                # Get action from Q-network
                feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
                Qs = sess.run(mainQN.output, feed_dict=feed)
                action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
    
            total_reward += reward
            
            if done:
                # the episode ends so no next state
                next_state = np.zeros(state.shape)
                t = max_steps
                
                print('Episode: {}'.format(ep),
                      'Total reward: {}'.format(total_reward),
                      'Training loss: {:.4f}'.format(loss),
                      'Explore P: {:.4f}'.format(explore_p))
                rewards_list.append((ep, total_reward))
                
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                
                # Start new episode
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                state = next_state
                t += 1
            
            # Sample mini-batch from memory
            batch = memory.sample(batch_size)
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            rewards = np.array([each[2] for each in batch])
            next_states = np.array([each[3] for each in batch])
            
            # Train network
            target_Qs = sess.run(mainQN.output, feed_dict={mainQN.inputs_: next_states})
            
            # Set target_Qs to 0 for states where episode ends
            episode_ends = (next_states == np.zeros(states[0].shape)).all(axis=1)
            target_Qs[episode_ends] = (0, 0)
            
            targets = rewards + gamma * np.max(target_Qs, axis=1)

            loss, _ = sess.run([mainQN.loss, mainQN.opt],
                                feed_dict={mainQN.inputs_: states,
                                           mainQN.targetQs_: targets,
                                           mainQN.actions_: actions})
        
    saver.save(sess, "checkpoints/cartpole.ckpt")
# Out:
# Episode: 1 Total reward: 10.0 Training loss: 1.0536 Explore P: 0.9990
# Episode: 2 Total reward: 13.0 Training loss: 1.0091 Explore P: 0.9977
# Episode: 3 Total reward: 11.0 Training loss: 1.0713 Explore P: 0.9966
# Episode: 4 Total reward: 20.0 Training loss: 1.1160 Explore P: 0.9947
# Episode: 5 Total reward: 15.0 Training loss: 1.0772 Explore P: 0.9932
# Episode: 6 Total reward: 15.0 Training loss: 1.1310 Explore P: 0.9917
# Episode: 7 Total reward: 16.0 Training loss: 1.1174 Explore P: 0.9901
# Episode: 8 Total reward: 12.0 Training loss: 1.1034 Explore P: 0.9890
# Episode: 9 Total reward: 13.0 Training loss: 1.2598 Explore P: 0.9877
# Episode: 10 Total reward: 18.0 Training loss: 1.2695 Explore P: 0.9859
# Episode: 11 Total reward: 14.0 Training loss: 1.2271 Explore P: 0.9846
# Episode: 12 Total reward: 13.0 Training loss: 1.3721 Explore P: 0.9833
# Episode: 13 Total reward: 16.0 Training loss: 1.4497 Explore P: 0.9818
# Episode: 14 Total reward: 10.0 Training loss: 1.3029 Explore P: 0.9808
# Episode: 15 Total reward: 9.0 Training loss: 1.3243 Explore P: 0.9799
# Episode: 16 Total reward: 11.0 Training loss: 1.5945 Explore P: 0.9788
# Episode: 17 Total reward: 22.0 Training loss: 1.6500 Explore P: 0.9767
# Episode: 18 Total reward: 21.0 Training loss: 1.5658 Explore P: 0.9747
# Episode: 19 Total reward: 15.0 Training loss: 1.9277 Explore P: 0.9732
# Episode: 20 Total reward: 11.0 Training loss: 1.7655 Explore P: 0.9722
# Episode: 21 Total reward: 10.0 Training loss: 1.6183 Explore P: 0.9712
# Episode: 22 Total reward: 16.0 Training loss: 1.7496 Explore P: 0.9697
# Episode: 23 Total reward: 15.0 Training loss: 1.9164 Explore P: 0.9682
# Episode: 24 Total reward: 17.0 Training loss: 1.7939 Explore P: 0.9666
# Episode: 25 Total reward: 64.0 Training loss: 4.0660 Explore P: 0.9605
# Episode: 26 Total reward: 13.0 Training loss: 2.0566 Explore P: 0.9593
# Episode: 27 Total reward: 16.0 Training loss: 2.1837 Explore P: 0.9578
# Episode: 28 Total reward: 15.0 Training loss: 2.5506 Explore P: 0.9563
# Episode: 29 Total reward: 10.0 Training loss: 4.8361 Explore P: 0.9554
# Episode: 30 Total reward: 13.0 Training loss: 2.7314 Explore P: 0.9542
# Episode: 31 Total reward: 29.0 Training loss: 3.8804 Explore P: 0.9514
# Episode: 32 Total reward: 10.0 Training loss: 3.2424 Explore P: 0.9505
# Episode: 33 Total reward: 19.0 Training loss: 2.9958 Explore P: 0.9487
# Episode: 34 Total reward: 11.0 Training loss: 2.4689 Explore P: 0.9477
# Episode: 35 Total reward: 16.0 Training loss: 5.2789 Explore P: 0.9462
# Episode: 36 Total reward: 19.0 Training loss: 15.4499 Explore P: 0.9444
# Episode: 37 Total reward: 36.0 Training loss: 6.3011 Explore P: 0.9410
# Episode: 38 Total reward: 18.0 Training loss: 8.6565 Explore P: 0.9394
# Episode: 39 Total reward: 16.0 Training loss: 8.5465 Explore P: 0.9379
# Episode: 40 Total reward: 14.0 Training loss: 18.2382 Explore P: 0.9366
# Episode: 41 Total reward: 35.0 Training loss: 12.4828 Explore P: 0.9333
# Episode: 42 Total reward: 18.0 Training loss: 6.5739 Explore P: 0.9317
# Episode: 43 Total reward: 10.0 Training loss: 10.1959 Explore P: 0.9308
# Episode: 44 Total reward: 15.0 Training loss: 12.7326 Explore P: 0.9294
# Episode: 45 Total reward: 20.0 Training loss: 3.8150 Explore P: 0.9275
# Episode: 46 Total reward: 11.0 Training loss: 4.0114 Explore P: 0.9265
# Episode: 47 Total reward: 8.0 Training loss: 16.5581 Explore P: 0.9258
# Episode: 48 Total reward: 13.0 Training loss: 6.5049 Explore P: 0.9246
# Episode: 49 Total reward: 15.0 Training loss: 6.4335 Explore P: 0.9232
# Episode: 50 Total reward: 19.0 Training loss: 15.2708 Explore P: 0.9215
# Episode: 51 Total reward: 11.0 Training loss: 28.5595 Explore P: 0.9205
# Episode: 52 Total reward: 9.0 Training loss: 6.4324 Explore P: 0.9197
# Episode: 53 Total reward: 18.0 Training loss: 48.8241 Explore P: 0.9181
# Episode: 54 Total reward: 17.0 Training loss: 5.2260 Explore P: 0.9165
# Episode: 55 Total reward: 12.0 Training loss: 6.8528 Explore P: 0.9154
# Episode: 56 Total reward: 36.0 Training loss: 5.7004 Explore P: 0.9122
# Episode: 57 Total reward: 11.0 Training loss: 16.9213 Explore P: 0.9112
# Episode: 58 Total reward: 13.0 Training loss: 6.3890 Explore P: 0.9100
# Episode: 59 Total reward: 12.0 Training loss: 34.1294 Explore P: 0.9089
# Episode: 60 Total reward: 8.0 Training loss: 6.7400 Explore P: 0.9082
# Episode: 61 Total reward: 11.0 Training loss: 43.3938 Explore P: 0.9072
# Episode: 62 Total reward: 17.0 Training loss: 31.0244 Explore P: 0.9057
# Episode: 63 Total reward: 15.0 Training loss: 9.3535 Explore P: 0.9044
# Episode: 64 Total reward: 10.0 Training loss: 29.1801 Explore P: 0.9035
# Episode: 65 Total reward: 24.0 Training loss: 18.0948 Explore P: 0.9013
# Episode: 66 Total reward: 22.0 Training loss: 7.4070 Explore P: 0.8994
# Episode: 67 Total reward: 23.0 Training loss: 132.3528 Explore P: 0.8973
# Episode: 68 Total reward: 16.0 Training loss: 9.7599 Explore P: 0.8959
# Episode: 69 Total reward: 26.0 Training loss: 88.6260 Explore P: 0.8936
# Episode: 70 Total reward: 27.0 Training loss: 56.2992 Explore P: 0.8912
# Episode: 71 Total reward: 8.0 Training loss: 27.7862 Explore P: 0.8905
# Episode: 72 Total reward: 37.0 Training loss: 53.1066 Explore P: 0.8873
# Episode: 73 Total reward: 24.0 Training loss: 58.2771 Explore P: 0.8852
# Episode: 74 Total reward: 10.0 Training loss: 29.1075 Explore P: 0.8843
# Episode: 75 Total reward: 21.0 Training loss: 17.0095 Explore P: 0.8824
# Episode: 76 Total reward: 9.0 Training loss: 7.7595 Explore P: 0.8817
# Episode: 77 Total reward: 54.0 Training loss: 25.4481 Explore P: 0.8770
# Episode: 78 Total reward: 10.0 Training loss: 9.8293 Explore P: 0.8761
# Episode: 79 Total reward: 26.0 Training loss: 10.6137 Explore P: 0.8739
# Episode: 80 Total reward: 13.0 Training loss: 89.6731 Explore P: 0.8727
# Episode: 81 Total reward: 10.0 Training loss: 56.9724 Explore P: 0.8719
# Episode: 82 Total reward: 10.0 Training loss: 45.3969 Explore P: 0.8710
# Episode: 83 Total reward: 21.0 Training loss: 45.4584 Explore P: 0.8692
# Episode: 84 Total reward: 13.0 Training loss: 47.9284 Explore P: 0.8681
# Episode: 85 Total reward: 12.0 Training loss: 137.5102 Explore P: 0.8671
# Episode: 86 Total reward: 11.0 Training loss: 100.0311 Explore P: 0.8661
# Episode: 87 Total reward: 9.0 Training loss: 44.3715 Explore P: 0.8653
# Episode: 88 Total reward: 11.0 Training loss: 10.7972 Explore P: 0.8644
# Episode: 89 Total reward: 9.0 Training loss: 29.5902 Explore P: 0.8636
# Episode: 90 Total reward: 11.0 Training loss: 70.2576 Explore P: 0.8627
# Episode: 91 Total reward: 25.0 Training loss: 45.0353 Explore P: 0.8606
# Episode: 92 Total reward: 9.0 Training loss: 115.6943 Explore P: 0.8598
# Episode: 93 Total reward: 8.0 Training loss: 62.6274 Explore P: 0.8591
# Episode: 94 Total reward: 23.0 Training loss: 29.7268 Explore P: 0.8572
# Episode: 95 Total reward: 14.0 Training loss: 16.7466 Explore P: 0.8560
# Episode: 96 Total reward: 15.0 Training loss: 62.5853 Explore P: 0.8547
# Episode: 97 Total reward: 17.0 Training loss: 61.7548 Explore P: 0.8533
# Episode: 98 Total reward: 18.0 Training loss: 11.1849 Explore P: 0.8518
# Episode: 99 Total reward: 12.0 Training loss: 29.9599 Explore P: 0.8508
# Episode: 100 Total reward: 10.0 Training loss: 16.3685 Explore P: 0.8499
# Episode: 101 Total reward: 11.0 Training loss: 96.9157 Explore P: 0.8490
# Episode: 102 Total reward: 15.0 Training loss: 107.6782 Explore P: 0.8477
# Episode: 103 Total reward: 13.0 Training loss: 35.2545 Explore P: 0.8466
# Episode: 104 Total reward: 9.0 Training loss: 62.1071 Explore P: 0.8459
# Episode: 105 Total reward: 10.0 Training loss: 33.3160 Explore P: 0.8451
# Episode: 106 Total reward: 22.0 Training loss: 13.3824 Explore P: 0.8432
# Episode: 107 Total reward: 13.0 Training loss: 124.2165 Explore P: 0.8421
# Episode: 108 Total reward: 31.0 Training loss: 30.8997 Explore P: 0.8396
# Episode: 109 Total reward: 10.0 Training loss: 157.0478 Explore P: 0.8387
# Episode: 110 Total reward: 10.0 Training loss: 58.5762 Explore P: 0.8379
# Episode: 111 Total reward: 12.0 Training loss: 112.0608 Explore P: 0.8369
# Episode: 112 Total reward: 21.0 Training loss: 14.7311 Explore P: 0.8352
# Episode: 113 Total reward: 9.0 Training loss: 129.2776 Explore P: 0.8344
# Episode: 114 Total reward: 22.0 Training loss: 12.6038 Explore P: 0.8326
# Episode: 115 Total reward: 11.0 Training loss: 98.5324 Explore P: 0.8317
# Episode: 116 Total reward: 12.0 Training loss: 39.1656 Explore P: 0.8307
# Episode: 117 Total reward: 17.0 Training loss: 57.8395 Explore P: 0.8293
# Episode: 118 Total reward: 26.0 Training loss: 267.8588 Explore P: 0.8272
# Episode: 119 Total reward: 19.0 Training loss: 11.1472 Explore P: 0.8257
# Episode: 120 Total reward: 13.0 Training loss: 125.1557 Explore P: 0.8246
# Episode: 121 Total reward: 18.0 Training loss: 13.5463 Explore P: 0.8231
# Episode: 122 Total reward: 14.0 Training loss: 42.5410 Explore P: 0.8220
# Episode: 123 Total reward: 14.0 Training loss: 145.1010 Explore P: 0.8209
# Episode: 124 Total reward: 17.0 Training loss: 262.4970 Explore P: 0.8195
# Episode: 125 Total reward: 10.0 Training loss: 232.0963 Explore P: 0.8187
# Episode: 126 Total reward: 29.0 Training loss: 61.4069 Explore P: 0.8163
# Episode: 127 Total reward: 10.0 Training loss: 51.5496 Explore P: 0.8155
# Episode: 128 Total reward: 10.0 Training loss: 13.1717 Explore P: 0.8147
# Episode: 129 Total reward: 19.0 Training loss: 101.8539 Explore P: 0.8132
# Episode: 130 Total reward: 11.0 Training loss: 13.8677 Explore P: 0.8123
# Episode: 131 Total reward: 15.0 Training loss: 48.8172 Explore P: 0.8111
# Episode: 132 Total reward: 14.0 Training loss: 119.4283 Explore P: 0.8100
# Episode: 133 Total reward: 7.0 Training loss: 170.9551 Explore P: 0.8094
# Episode: 134 Total reward: 15.0 Training loss: 75.7948 Explore P: 0.8082
# Episode: 135 Total reward: 18.0 Training loss: 79.2812 Explore P: 0.8068
# Episode: 136 Total reward: 17.0 Training loss: 54.5960 Explore P: 0.8054
# Episode: 137 Total reward: 9.0 Training loss: 138.6984 Explore P: 0.8047
# Episode: 138 Total reward: 21.0 Training loss: 75.4397 Explore P: 0.8031
# Episode: 139 Total reward: 16.0 Training loss: 108.7725 Explore P: 0.8018
# Episode: 140 Total reward: 15.0 Training loss: 51.8888 Explore P: 0.8006
# Episode: 141 Total reward: 11.0 Training loss: 87.8618 Explore P: 0.7997
# Episode: 142 Total reward: 14.0 Training loss: 88.0371 Explore P: 0.7986
# Episode: 143 Total reward: 14.0 Training loss: 175.8321 Explore P: 0.7975
# Episode: 144 Total reward: 13.0 Training loss: 82.2246 Explore P: 0.7965
# Episode: 145 Total reward: 24.0 Training loss: 12.0896 Explore P: 0.7946
# Episode: 146 Total reward: 8.0 Training loss: 11.9343 Explore P: 0.7940
# Episode: 147 Total reward: 24.0 Training loss: 9.9358 Explore P: 0.7921
# Episode: 148 Total reward: 18.0 Training loss: 9.8193 Explore P: 0.7907
# Episode: 149 Total reward: 11.0 Training loss: 67.2942 Explore P: 0.7899
# Episode: 150 Total reward: 39.0 Training loss: 52.8914 Explore P: 0.7868
# Episode: 151 Total reward: 14.0 Training loss: 219.7141 Explore P: 0.7857
# Episode: 152 Total reward: 23.0 Training loss: 87.7386 Explore P: 0.7839
# Episode: 153 Total reward: 27.0 Training loss: 11.1887 Explore P: 0.7819
# Episode: 154 Total reward: 22.0 Training loss: 190.6910 Explore P: 0.7802
# Episode: 155 Total reward: 19.0 Training loss: 95.6664 Explore P: 0.7787
# Episode: 156 Total reward: 11.0 Training loss: 12.9013 Explore P: 0.7779
# Episode: 157 Total reward: 18.0 Training loss: 149.9515 Explore P: 0.7765
# Episode: 158 Total reward: 14.0 Training loss: 63.3389 Explore P: 0.7754
# Episode: 159 Total reward: 21.0 Training loss: 12.1519 Explore P: 0.7738
# Episode: 160 Total reward: 13.0 Training loss: 93.5225 Explore P: 0.7728
# Episode: 161 Total reward: 21.0 Training loss: 162.7106 Explore P: 0.7712
# Episode: 162 Total reward: 30.0 Training loss: 9.1919 Explore P: 0.7689
# Episode: 163 Total reward: 25.0 Training loss: 11.0786 Explore P: 0.7670
# Episode: 164 Total reward: 38.0 Training loss: 8.3730 Explore P: 0.7642
# Episode: 165 Total reward: 12.0 Training loss: 10.4757 Explore P: 0.7633
# Episode: 166 Total reward: 21.0 Training loss: 106.8420 Explore P: 0.7617
# Episode: 167 Total reward: 17.0 Training loss: 60.3186 Explore P: 0.7604
# Episode: 168 Total reward: 12.0 Training loss: 151.6335 Explore P: 0.7595
# Episode: 169 Total reward: 19.0 Training loss: 111.4741 Explore P: 0.7581
# Episode: 170 Total reward: 11.0 Training loss: 239.1224 Explore P: 0.7573
# Episode: 171 Total reward: 15.0 Training loss: 73.3424 Explore P: 0.7561
# Episode: 172 Total reward: 8.0 Training loss: 10.3320 Explore P: 0.7555
# Episode: 173 Total reward: 22.0 Training loss: 7.0975 Explore P: 0.7539
# Episode: 174 Total reward: 19.0 Training loss: 63.3065 Explore P: 0.7525
# Episode: 175 Total reward: 15.0 Training loss: 132.9204 Explore P: 0.7514
# Episode: 176 Total reward: 22.0 Training loss: 156.7051 Explore P: 0.7497
# Episode: 177 Total reward: 14.0 Training loss: 7.5215 Explore P: 0.7487
# Episode: 178 Total reward: 42.0 Training loss: 54.8826 Explore P: 0.7456
# Episode: 179 Total reward: 8.0 Training loss: 94.6500 Explore P: 0.7450
# Episode: 180 Total reward: 28.0 Training loss: 6.7000 Explore P: 0.7430
# Episode: 181 Total reward: 11.0 Training loss: 192.7064 Explore P: 0.7422
# Episode: 182 Total reward: 22.0 Training loss: 271.6529 Explore P: 0.7406
# Episode: 183 Total reward: 29.0 Training loss: 119.0379 Explore P: 0.7384
# Episode: 184 Total reward: 15.0 Training loss: 104.5038 Explore P: 0.7373
# Episode: 185 Total reward: 8.0 Training loss: 90.4537 Explore P: 0.7368
# Episode: 186 Total reward: 18.0 Training loss: 86.9952 Explore P: 0.7355
# Episode: 187 Total reward: 28.0 Training loss: 141.0945 Explore P: 0.7334
# Episode: 188 Total reward: 10.0 Training loss: 4.2151 Explore P: 0.7327
# Episode: 189 Total reward: 11.0 Training loss: 69.2854 Explore P: 0.7319
# Episode: 190 Total reward: 11.0 Training loss: 50.7569 Explore P: 0.7311
# Episode: 191 Total reward: 27.0 Training loss: 212.8537 Explore P: 0.7292
# Episode: 192 Total reward: 10.0 Training loss: 183.6337 Explore P: 0.7285
# Episode: 193 Total reward: 22.0 Training loss: 49.9523 Explore P: 0.7269
# Episode: 194 Total reward: 20.0 Training loss: 4.0068 Explore P: 0.7254
# Episode: 195 Total reward: 28.0 Training loss: 48.9359 Explore P: 0.7234
# Episode: 196 Total reward: 22.0 Training loss: 4.1124 Explore P: 0.7219
# Episode: 197 Total reward: 26.0 Training loss: 164.1071 Explore P: 0.7200
# Episode: 198 Total reward: 12.0 Training loss: 4.2201 Explore P: 0.7192
# Episode: 199 Total reward: 12.0 Training loss: 83.7013 Explore P: 0.7183
# Episode: 200 Total reward: 42.0 Training loss: 71.2192 Explore P: 0.7154
# Episode: 201 Total reward: 15.0 Training loss: 3.3427 Explore P: 0.7143
# Episode: 202 Total reward: 22.0 Training loss: 130.5537 Explore P: 0.7128
# Episode: 203 Total reward: 23.0 Training loss: 3.7110 Explore P: 0.7111
# Episode: 204 Total reward: 14.0 Training loss: 45.3556 Explore P: 0.7102
# Episode: 205 Total reward: 20.0 Training loss: 47.4907 Explore P: 0.7088
# Episode: 206 Total reward: 21.0 Training loss: 165.2240 Explore P: 0.7073
# Episode: 207 Total reward: 12.0 Training loss: 91.6058 Explore P: 0.7065
# Episode: 208 Total reward: 15.0 Training loss: 56.3404 Explore P: 0.7054
# Episode: 209 Total reward: 11.0 Training loss: 65.1312 Explore P: 0.7046
# Episode: 210 Total reward: 10.0 Training loss: 3.3475 Explore P: 0.7040
# Episode: 211 Total reward: 16.0 Training loss: 73.9790 Explore P: 0.7028
# Episode: 212 Total reward: 13.0 Training loss: 62.5545 Explore P: 0.7019
# Episode: 213 Total reward: 16.0 Training loss: 120.4922 Explore P: 0.7008
# Episode: 214 Total reward: 9.0 Training loss: 53.5612 Explore P: 0.7002
# Episode: 215 Total reward: 12.0 Training loss: 162.6986 Explore P: 0.6994
# Episode: 216 Total reward: 10.0 Training loss: 2.4481 Explore P: 0.6987
# Episode: 217 Total reward: 12.0 Training loss: 2.5856 Explore P: 0.6979
# Episode: 218 Total reward: 13.0 Training loss: 49.9967 Explore P: 0.6970
# Episode: 219 Total reward: 24.0 Training loss: 45.2293 Explore P: 0.6953
# Episode: 220 Total reward: 16.0 Training loss: 2.6045 Explore P: 0.6942
# Episode: 221 Total reward: 22.0 Training loss: 105.1195 Explore P: 0.6927
# Episode: 222 Total reward: 13.0 Training loss: 1.9274 Explore P: 0.6918
# Episode: 223 Total reward: 18.0 Training loss: 88.1737 Explore P: 0.6906
# Episode: 224 Total reward: 9.0 Training loss: 2.3262 Explore P: 0.6900
# Episode: 225 Total reward: 9.0 Training loss: 122.3385 Explore P: 0.6894
# Episode: 226 Total reward: 11.0 Training loss: 82.6275 Explore P: 0.6886
# Episode: 227 Total reward: 10.0 Training loss: 135.2440 Explore P: 0.6880
# Episode: 228 Total reward: 14.0 Training loss: 35.9801 Explore P: 0.6870
# Episode: 229 Total reward: 10.0 Training loss: 55.9656 Explore P: 0.6863
# Episode: 230 Total reward: 15.0 Training loss: 1.9824 Explore P: 0.6853
# Episode: 231 Total reward: 25.0 Training loss: 38.8795 Explore P: 0.6836
# Episode: 232 Total reward: 14.0 Training loss: 159.5613 Explore P: 0.6827
# Episode: 233 Total reward: 12.0 Training loss: 47.3021 Explore P: 0.6819
# Episode: 234 Total reward: 11.0 Training loss: 44.0156 Explore P: 0.6812
# Episode: 235 Total reward: 13.0 Training loss: 1.2967 Explore P: 0.6803
# Episode: 236 Total reward: 11.0 Training loss: 34.2626 Explore P: 0.6795
# Episode: 237 Total reward: 12.0 Training loss: 1.2418 Explore P: 0.6787
# Episode: 238 Total reward: 11.0 Training loss: 41.8214 Explore P: 0.6780
# Episode: 239 Total reward: 39.0 Training loss: 70.2540 Explore P: 0.6754
# Episode: 240 Total reward: 12.0 Training loss: 95.2884 Explore P: 0.6746
# Episode: 241 Total reward: 16.0 Training loss: 29.3347 Explore P: 0.6736
# Episode: 242 Total reward: 13.0 Training loss: 61.3306 Explore P: 0.6727
# Episode: 243 Total reward: 9.0 Training loss: 55.4985 Explore P: 0.6721
# Episode: 244 Total reward: 16.0 Training loss: 28.1999 Explore P: 0.6710
# Episode: 245 Total reward: 15.0 Training loss: 53.6139 Explore P: 0.6700
# Episode: 246 Total reward: 19.0 Training loss: 27.8421 Explore P: 0.6688
# Episode: 247 Total reward: 10.0 Training loss: 27.0793 Explore P: 0.6681
# Episode: 248 Total reward: 22.0 Training loss: 26.4817 Explore P: 0.6667
# Episode: 249 Total reward: 21.0 Training loss: 73.6176 Explore P: 0.6653
# Episode: 250 Total reward: 18.0 Training loss: 1.7702 Explore P: 0.6641
# Episode: 251 Total reward: 14.0 Training loss: 87.0510 Explore P: 0.6632
# Episode: 252 Total reward: 10.0 Training loss: 23.9475 Explore P: 0.6626
# Episode: 253 Total reward: 12.0 Training loss: 24.5185 Explore P: 0.6618
# Episode: 254 Total reward: 30.0 Training loss: 1.3036 Explore P: 0.6598
# Episode: 255 Total reward: 12.0 Training loss: 109.2155 Explore P: 0.6590
# Episode: 256 Total reward: 11.0 Training loss: 21.9856 Explore P: 0.6583
# Episode: 257 Total reward: 15.0 Training loss: 54.2949 Explore P: 0.6574
# Episode: 258 Total reward: 16.0 Training loss: 0.6984 Explore P: 0.6563
# Episode: 259 Total reward: 12.0 Training loss: 2.2770 Explore P: 0.6556
# Episode: 260 Total reward: 21.0 Training loss: 20.4241 Explore P: 0.6542
# Episode: 261 Total reward: 14.0 Training loss: 20.3551 Explore P: 0.6533
# Episode: 262 Total reward: 21.0 Training loss: 20.0465 Explore P: 0.6519
# Episode: 263 Total reward: 17.0 Training loss: 19.9447 Explore P: 0.6509
# Episode: 264 Total reward: 16.0 Training loss: 18.8725 Explore P: 0.6498
# Episode: 265 Total reward: 42.0 Training loss: 32.0484 Explore P: 0.6471
# Episode: 266 Total reward: 17.0 Training loss: 3.0758 Explore P: 0.6461
# Episode: 267 Total reward: 13.0 Training loss: 2.3828 Explore P: 0.6452
# Episode: 268 Total reward: 14.0 Training loss: 18.5361 Explore P: 0.6444
# Episode: 269 Total reward: 45.0 Training loss: 2.0167 Explore P: 0.6415
# Episode: 270 Total reward: 20.0 Training loss: 24.0739 Explore P: 0.6402
# Episode: 271 Total reward: 10.0 Training loss: 35.0352 Explore P: 0.6396
# Episode: 272 Total reward: 13.0 Training loss: 32.6196 Explore P: 0.6388
# Episode: 273 Total reward: 17.0 Training loss: 16.2572 Explore P: 0.6377
# Episode: 274 Total reward: 18.0 Training loss: 50.1728 Explore P: 0.6366
# Episode: 275 Total reward: 32.0 Training loss: 2.0214 Explore P: 0.6346
# Episode: 276 Total reward: 9.0 Training loss: 81.8639 Explore P: 0.6340
# Episode: 277 Total reward: 16.0 Training loss: 1.3169 Explore P: 0.6330
# Episode: 278 Total reward: 14.0 Training loss: 33.5272 Explore P: 0.6322
# Episode: 279 Total reward: 11.0 Training loss: 40.5073 Explore P: 0.6315
# Episode: 280 Total reward: 22.0 Training loss: 21.4987 Explore P: 0.6301
# Episode: 281 Total reward: 17.0 Training loss: 31.5806 Explore P: 0.6291
# Episode: 282 Total reward: 20.0 Training loss: 1.3240 Explore P: 0.6278
# Episode: 283 Total reward: 46.0 Training loss: 17.8170 Explore P: 0.6250
# Episode: 284 Total reward: 22.0 Training loss: 1.5504 Explore P: 0.6236
# Episode: 285 Total reward: 31.0 Training loss: 41.0109 Explore P: 0.6217
# Episode: 286 Total reward: 13.0 Training loss: 56.9606 Explore P: 0.6209
# Episode: 287 Total reward: 11.0 Training loss: 1.3199 Explore P: 0.6203
# Episode: 288 Total reward: 34.0 Training loss: 1.4762 Explore P: 0.6182
# Episode: 289 Total reward: 13.0 Training loss: 1.2339 Explore P: 0.6174
# Episode: 290 Total reward: 18.0 Training loss: 1.2450 Explore P: 0.6163
# Episode: 291 Total reward: 9.0 Training loss: 1.1245 Explore P: 0.6158
# Episode: 292 Total reward: 19.0 Training loss: 41.8634 Explore P: 0.6146
# Episode: 293 Total reward: 40.0 Training loss: 58.9795 Explore P: 0.6122
# Episode: 294 Total reward: 15.0 Training loss: 2.0115 Explore P: 0.6113
# Episode: 295 Total reward: 33.0 Training loss: 80.6810 Explore P: 0.6093
# Episode: 296 Total reward: 12.0 Training loss: 32.6301 Explore P: 0.6086
# Episode: 297 Total reward: 11.0 Training loss: 54.6308 Explore P: 0.6079
# Episode: 298 Total reward: 16.0 Training loss: 17.7988 Explore P: 0.6070
# Episode: 299 Total reward: 33.0 Training loss: 25.2305 Explore P: 0.6050
# Episode: 300 Total reward: 30.0 Training loss: 58.1090 Explore P: 0.6032
# Episode: 301 Total reward: 20.0 Training loss: 26.6790 Explore P: 0.6021
# Episode: 302 Total reward: 17.0 Training loss: 25.1228 Explore P: 0.6011
# Episode: 303 Total reward: 13.0 Training loss: 1.2055 Explore P: 0.6003
# Episode: 304 Total reward: 24.0 Training loss: 14.0466 Explore P: 0.5989
# Episode: 305 Total reward: 21.0 Training loss: 2.1386 Explore P: 0.5976
# Episode: 306 Total reward: 13.0 Training loss: 0.9793 Explore P: 0.5969
# Episode: 307 Total reward: 24.0 Training loss: 1.1654 Explore P: 0.5955
# Episode: 308 Total reward: 21.0 Training loss: 13.6955 Explore P: 0.5942
# Episode: 309 Total reward: 22.0 Training loss: 28.9441 Explore P: 0.5930
# Episode: 310 Total reward: 29.0 Training loss: 13.4381 Explore P: 0.5913
# Episode: 311 Total reward: 39.0 Training loss: 14.5079 Explore P: 0.5890
# Episode: 312 Total reward: 15.0 Training loss: 24.9322 Explore P: 0.5881
# Episode: 313 Total reward: 42.0 Training loss: 23.0940 Explore P: 0.5857
# Episode: 314 Total reward: 34.0 Training loss: 10.4776 Explore P: 0.5838
# Episode: 315 Total reward: 19.0 Training loss: 9.3897 Explore P: 0.5827
# Episode: 316 Total reward: 48.0 Training loss: 33.8582 Explore P: 0.5799
# Episode: 317 Total reward: 20.0 Training loss: 42.4982 Explore P: 0.5788
# Episode: 318 Total reward: 22.0 Training loss: 27.3992 Explore P: 0.5775
# Episode: 319 Total reward: 19.0 Training loss: 1.4623 Explore P: 0.5765
# Episode: 320 Total reward: 38.0 Training loss: 22.4994 Explore P: 0.5743
# Episode: 321 Total reward: 52.0 Training loss: 27.0085 Explore P: 0.5714
# Episode: 322 Total reward: 9.0 Training loss: 12.5036 Explore P: 0.5709
# Episode: 323 Total reward: 15.0 Training loss: 92.5831 Explore P: 0.5700
# Episode: 324 Total reward: 23.0 Training loss: 0.7846 Explore P: 0.5688
# Episode: 325 Total reward: 20.0 Training loss: 14.1697 Explore P: 0.5676
# Episode: 326 Total reward: 28.0 Training loss: 19.8265 Explore P: 0.5661
# Episode: 327 Total reward: 27.0 Training loss: 34.7427 Explore P: 0.5646
# Episode: 328 Total reward: 22.0 Training loss: 14.3986 Explore P: 0.5634
# Episode: 329 Total reward: 27.0 Training loss: 1.4018 Explore P: 0.5619
# Episode: 330 Total reward: 65.0 Training loss: 11.8218 Explore P: 0.5583
# Episode: 331 Total reward: 19.0 Training loss: 0.8474 Explore P: 0.5572
# Episode: 332 Total reward: 15.0 Training loss: 2.3291 Explore P: 0.5564
# Episode: 333 Total reward: 34.0 Training loss: 9.7023 Explore P: 0.5546
# Episode: 334 Total reward: 8.0 Training loss: 2.0274 Explore P: 0.5541
# Episode: 335 Total reward: 35.0 Training loss: 8.9727 Explore P: 0.5522
# Episode: 336 Total reward: 29.0 Training loss: 45.0590 Explore P: 0.5507
# Episode: 337 Total reward: 51.0 Training loss: 26.5233 Explore P: 0.5479
# Episode: 338 Total reward: 20.0 Training loss: 45.5647 Explore P: 0.5468
# Episode: 339 Total reward: 44.0 Training loss: 14.0693 Explore P: 0.5445
# Episode: 340 Total reward: 32.0 Training loss: 13.2169 Explore P: 0.5428
# Episode: 341 Total reward: 19.0 Training loss: 1.5268 Explore P: 0.5418
# Episode: 342 Total reward: 74.0 Training loss: 12.9672 Explore P: 0.5378
# Episode: 343 Total reward: 26.0 Training loss: 77.1593 Explore P: 0.5365
# Episode: 344 Total reward: 13.0 Training loss: 9.8706 Explore P: 0.5358
# Episode: 345 Total reward: 28.0 Training loss: 12.1760 Explore P: 0.5343
# Episode: 346 Total reward: 26.0 Training loss: 21.0234 Explore P: 0.5330
# Episode: 347 Total reward: 68.0 Training loss: 12.1402 Explore P: 0.5294
# Episode: 348 Total reward: 37.0 Training loss: 10.1660 Explore P: 0.5275
# Episode: 349 Total reward: 13.0 Training loss: 34.2208 Explore P: 0.5268
# Episode: 350 Total reward: 15.0 Training loss: 1.5698 Explore P: 0.5261
# Episode: 351 Total reward: 21.0 Training loss: 1.2224 Explore P: 0.5250
# Episode: 352 Total reward: 33.0 Training loss: 22.8030 Explore P: 0.5233
# Episode: 353 Total reward: 14.0 Training loss: 24.5691 Explore P: 0.5226
# Episode: 354 Total reward: 26.0 Training loss: 20.2712 Explore P: 0.5212
# Episode: 355 Total reward: 23.0 Training loss: 26.0574 Explore P: 0.5200
# Episode: 356 Total reward: 34.0 Training loss: 0.7684 Explore P: 0.5183
# Episode: 357 Total reward: 54.0 Training loss: 1.0529 Explore P: 0.5156
# Episode: 358 Total reward: 20.0 Training loss: 14.0898 Explore P: 0.5146
# Episode: 359 Total reward: 77.0 Training loss: 36.4169 Explore P: 0.5107
# Episode: 360 Total reward: 42.0 Training loss: 0.9139 Explore P: 0.5086
# Episode: 361 Total reward: 33.0 Training loss: 15.5381 Explore P: 0.5070
# Episode: 362 Total reward: 34.0 Training loss: 1.2893 Explore P: 0.5053
# Episode: 363 Total reward: 31.0 Training loss: 1.2124 Explore P: 0.5037
# Episode: 364 Total reward: 22.0 Training loss: 15.4265 Explore P: 0.5027
# Episode: 365 Total reward: 33.0 Training loss: 1.2994 Explore P: 0.5010
# Episode: 366 Total reward: 16.0 Training loss: 10.9937 Explore P: 0.5002
# Episode: 367 Total reward: 21.0 Training loss: 10.2023 Explore P: 0.4992
# Episode: 368 Total reward: 15.0 Training loss: 17.3100 Explore P: 0.4985
# Episode: 369 Total reward: 19.0 Training loss: 16.8546 Explore P: 0.4976
# Episode: 370 Total reward: 28.0 Training loss: 57.5284 Explore P: 0.4962
# Episode: 371 Total reward: 29.0 Training loss: 16.6114 Explore P: 0.4948
# Episode: 372 Total reward: 23.0 Training loss: 14.4067 Explore P: 0.4937
# Episode: 373 Total reward: 23.0 Training loss: 0.9212 Explore P: 0.4926
# Episode: 374 Total reward: 24.0 Training loss: 47.6019 Explore P: 0.4914
# Episode: 375 Total reward: 51.0 Training loss: 45.7847 Explore P: 0.4890
# Episode: 376 Total reward: 19.0 Training loss: 29.0308 Explore P: 0.4880
# Episode: 377 Total reward: 17.0 Training loss: 17.6289 Explore P: 0.4872
# Episode: 378 Total reward: 16.0 Training loss: 1.2252 Explore P: 0.4865
# Episode: 379 Total reward: 41.0 Training loss: 1.9050 Explore P: 0.4845
# Episode: 380 Total reward: 20.0 Training loss: 9.2885 Explore P: 0.4836
# Episode: 381 Total reward: 28.0 Training loss: 13.8361 Explore P: 0.4822
# Episode: 382 Total reward: 43.0 Training loss: 29.5855 Explore P: 0.4802
# Episode: 383 Total reward: 13.0 Training loss: 11.9458 Explore P: 0.4796
# Episode: 384 Total reward: 28.0 Training loss: 1.2182 Explore P: 0.4783
# Episode: 385 Total reward: 24.0 Training loss: 2.0957 Explore P: 0.4772
# Episode: 386 Total reward: 27.0 Training loss: 24.7682 Explore P: 0.4759
# Episode: 387 Total reward: 17.0 Training loss: 30.5471 Explore P: 0.4751
# Episode: 388 Total reward: 30.0 Training loss: 14.5391 Explore P: 0.4737
# Episode: 389 Total reward: 41.0 Training loss: 1.0728 Explore P: 0.4718
# Episode: 390 Total reward: 28.0 Training loss: 26.4015 Explore P: 0.4705
# Episode: 391 Total reward: 26.0 Training loss: 26.2863 Explore P: 0.4693
# Episode: 392 Total reward: 49.0 Training loss: 24.8547 Explore P: 0.4671
# Episode: 393 Total reward: 38.0 Training loss: 12.8813 Explore P: 0.4654
# Episode: 394 Total reward: 11.0 Training loss: 17.2350 Explore P: 0.4649
# Episode: 395 Total reward: 16.0 Training loss: 25.7263 Explore P: 0.4641
# Episode: 396 Total reward: 67.0 Training loss: 35.6055 Explore P: 0.4611
# Episode: 397 Total reward: 38.0 Training loss: 1.0871 Explore P: 0.4594
# Episode: 398 Total reward: 33.0 Training loss: 14.6688 Explore P: 0.4579
# Episode: 399 Total reward: 29.0 Training loss: 24.9177 Explore P: 0.4566
# Episode: 400 Total reward: 21.0 Training loss: 11.1347 Explore P: 0.4557
# Episode: 401 Total reward: 24.0 Training loss: 0.7394 Explore P: 0.4546
# Episode: 402 Total reward: 22.0 Training loss: 42.7241 Explore P: 0.4536
# Episode: 403 Total reward: 27.0 Training loss: 13.0463 Explore P: 0.4524
# Episode: 404 Total reward: 22.0 Training loss: 17.3296 Explore P: 0.4515
# Episode: 405 Total reward: 21.0 Training loss: 1.2088 Explore P: 0.4505
# Episode: 406 Total reward: 29.0 Training loss: 18.2629 Explore P: 0.4493
# Episode: 407 Total reward: 44.0 Training loss: 8.7578 Explore P: 0.4473
# Episode: 408 Total reward: 37.0 Training loss: 1.0796 Explore P: 0.4457
# Episode: 409 Total reward: 28.0 Training loss: 14.7584 Explore P: 0.4445
# Episode: 410 Total reward: 48.0 Training loss: 22.0148 Explore P: 0.4424
# Episode: 411 Total reward: 21.0 Training loss: 17.6737 Explore P: 0.4415
# Episode: 412 Total reward: 27.0 Training loss: 1.5660 Explore P: 0.4404
# Episode: 413 Total reward: 13.0 Training loss: 7.3032 Explore P: 0.4398
# Episode: 414 Total reward: 23.0 Training loss: 16.4000 Explore P: 0.4388
# Episode: 415 Total reward: 23.0 Training loss: 14.3836 Explore P: 0.4378
# Episode: 416 Total reward: 22.0 Training loss: 19.9732 Explore P: 0.4369
# Episode: 417 Total reward: 126.0 Training loss: 1.4513 Explore P: 0.4315
# Episode: 418 Total reward: 77.0 Training loss: 38.4435 Explore P: 0.4283
# Episode: 419 Total reward: 23.0 Training loss: 1.1388 Explore P: 0.4273
# Episode: 420 Total reward: 41.0 Training loss: 21.0658 Explore P: 0.4256
# Episode: 421 Total reward: 36.0 Training loss: 1.5902 Explore P: 0.4241
# Episode: 422 Total reward: 47.0 Training loss: 31.2062 Explore P: 0.4222
# Episode: 423 Total reward: 85.0 Training loss: 14.7171 Explore P: 0.4187
# Episode: 424 Total reward: 39.0 Training loss: 17.5534 Explore P: 0.4171
# Episode: 425 Total reward: 96.0 Training loss: 14.7017 Explore P: 0.4132
# Episode: 426 Total reward: 41.0 Training loss: 1.3708 Explore P: 0.4116
# Episode: 427 Total reward: 44.0 Training loss: 23.7687 Explore P: 0.4098
# Episode: 428 Total reward: 19.0 Training loss: 1.8009 Explore P: 0.4091
# Episode: 429 Total reward: 20.0 Training loss: 0.9457 Explore P: 0.4083
# Episode: 430 Total reward: 30.0 Training loss: 8.7936 Explore P: 0.4071
# Episode: 431 Total reward: 22.0 Training loss: 33.4113 Explore P: 0.4062
# Episode: 432 Total reward: 34.0 Training loss: 18.9177 Explore P: 0.4048
# Episode: 433 Total reward: 27.0 Training loss: 1.0793 Explore P: 0.4038
# Episode: 434 Total reward: 60.0 Training loss: 12.5051 Explore P: 0.4014
# Episode: 435 Total reward: 48.0 Training loss: 12.3870 Explore P: 0.3996
# Episode: 436 Total reward: 34.0 Training loss: 10.3992 Explore P: 0.3982
# Episode: 437 Total reward: 27.0 Training loss: 22.4278 Explore P: 0.3972
# Episode: 438 Total reward: 48.0 Training loss: 2.1661 Explore P: 0.3953
# Episode: 439 Total reward: 52.0 Training loss: 2.1430 Explore P: 0.3933
# Episode: 440 Total reward: 46.0 Training loss: 6.1673 Explore P: 0.3916
# Episode: 441 Total reward: 29.0 Training loss: 0.7888 Explore P: 0.3905
# Episode: 442 Total reward: 41.0 Training loss: 1.6041 Explore P: 0.3889
# Episode: 443 Total reward: 86.0 Training loss: 19.8339 Explore P: 0.3857
# Episode: 444 Total reward: 36.0 Training loss: 11.8872 Explore P: 0.3843
# Episode: 445 Total reward: 30.0 Training loss: 1.1626 Explore P: 0.3832
# Episode: 446 Total reward: 62.0 Training loss: 29.3916 Explore P: 0.3809
# Episode: 447 Total reward: 24.0 Training loss: 46.1261 Explore P: 0.3800
# Episode: 448 Total reward: 21.0 Training loss: 41.1784 Explore P: 0.3792
# Episode: 449 Total reward: 30.0 Training loss: 20.2597 Explore P: 0.3781
# Episode: 450 Total reward: 28.0 Training loss: 19.4216 Explore P: 0.3771
# Episode: 451 Total reward: 47.0 Training loss: 19.6227 Explore P: 0.3754
# Episode: 452 Total reward: 42.0 Training loss: 19.2512 Explore P: 0.3738
# Episode: 453 Total reward: 30.0 Training loss: 1.7479 Explore P: 0.3727
# Episode: 454 Total reward: 54.0 Training loss: 1.8209 Explore P: 0.3708
# Episode: 455 Total reward: 60.0 Training loss: 82.1994 Explore P: 0.3686
# Episode: 456 Total reward: 47.0 Training loss: 21.9705 Explore P: 0.3670
# Episode: 457 Total reward: 33.0 Training loss: 2.9957 Explore P: 0.3658
# Episode: 458 Total reward: 37.0 Training loss: 22.2851 Explore P: 0.3645
# Episode: 459 Total reward: 86.0 Training loss: 23.6362 Explore P: 0.3614
# Episode: 460 Total reward: 70.0 Training loss: 27.6223 Explore P: 0.3590
# Episode: 461 Total reward: 63.0 Training loss: 70.2055 Explore P: 0.3568
# Episode: 462 Total reward: 82.0 Training loss: 0.7432 Explore P: 0.3540
# Episode: 463 Total reward: 72.0 Training loss: 20.0801 Explore P: 0.3515
# Episode: 464 Total reward: 97.0 Training loss: 32.7316 Explore P: 0.3482
# Episode: 465 Total reward: 36.0 Training loss: 1.5920 Explore P: 0.3470
# Episode: 466 Total reward: 117.0 Training loss: 48.1551 Explore P: 0.3431
# Episode: 467 Total reward: 31.0 Training loss: 1.1466 Explore P: 0.3420
# Episode: 468 Total reward: 138.0 Training loss: 2.4744 Explore P: 0.3375
# Episode: 469 Total reward: 98.0 Training loss: 0.8503 Explore P: 0.3343
# Episode: 470 Total reward: 53.0 Training loss: 1.0867 Explore P: 0.3326
# Episode: 471 Total reward: 93.0 Training loss: 30.4066 Explore P: 0.3296
# Episode: 472 Total reward: 68.0 Training loss: 1.5329 Explore P: 0.3274
# Episode: 473 Total reward: 46.0 Training loss: 25.0587 Explore P: 0.3260
# Episode: 474 Total reward: 79.0 Training loss: 28.4452 Explore P: 0.3235
# Episode: 475 Total reward: 41.0 Training loss: 2.4336 Explore P: 0.3222
# Episode: 476 Total reward: 81.0 Training loss: 28.5393 Explore P: 0.3197
# Episode: 477 Total reward: 66.0 Training loss: 1.9899 Explore P: 0.3176
# Episode: 478 Total reward: 43.0 Training loss: 1.6382 Explore P: 0.3163
# Episode: 479 Total reward: 41.0 Training loss: 34.3679 Explore P: 0.3151
# Episode: 480 Total reward: 43.0 Training loss: 1.8283 Explore P: 0.3137
# Episode: 481 Total reward: 61.0 Training loss: 2.4468 Explore P: 0.3119
# Episode: 482 Total reward: 83.0 Training loss: 33.0094 Explore P: 0.3094
# Episode: 483 Total reward: 82.0 Training loss: 0.8343 Explore P: 0.3070
# Episode: 484 Total reward: 66.0 Training loss: 1.4935 Explore P: 0.3050
# Episode: 485 Total reward: 72.0 Training loss: 1.3857 Explore P: 0.3029
# Episode: 486 Total reward: 110.0 Training loss: 45.3449 Explore P: 0.2997
# Episode: 487 Total reward: 41.0 Training loss: 1.0468 Explore P: 0.2985
# Episode: 488 Total reward: 54.0 Training loss: 57.7034 Explore P: 0.2969
# Episode: 489 Total reward: 55.0 Training loss: 1.2830 Explore P: 0.2954
# Episode: 490 Total reward: 60.0 Training loss: 34.1396 Explore P: 0.2937
# Episode: 491 Total reward: 136.0 Training loss: 50.7875 Explore P: 0.2898
# Episode: 492 Total reward: 41.0 Training loss: 54.1077 Explore P: 0.2887
# Episode: 493 Total reward: 49.0 Training loss: 53.0065 Explore P: 0.2873
# Episode: 494 Total reward: 33.0 Training loss: 1.6922 Explore P: 0.2864
# Episode: 495 Total reward: 69.0 Training loss: 2.0751 Explore P: 0.2845
# Episode: 496 Total reward: 84.0 Training loss: 1.2848 Explore P: 0.2822
# Episode: 497 Total reward: 55.0 Training loss: 1.3433 Explore P: 0.2807
# Episode: 498 Total reward: 180.0 Training loss: 2.5958 Explore P: 0.2759
# Episode: 499 Total reward: 71.0 Training loss: 26.2653 Explore P: 0.2740
# Episode: 500 Total reward: 38.0 Training loss: 1.6331 Explore P: 0.2730
# Episode: 501 Total reward: 136.0 Training loss: 1.6426 Explore P: 0.2695
# Episode: 502 Total reward: 81.0 Training loss: 38.8386 Explore P: 0.2674
# Episode: 503 Total reward: 45.0 Training loss: 284.4955 Explore P: 0.2662
# Episode: 504 Total reward: 51.0 Training loss: 21.4597 Explore P: 0.2649
# Episode: 505 Total reward: 54.0 Training loss: 1.1142 Explore P: 0.2635
# Episode: 506 Total reward: 70.0 Training loss: 1.4719 Explore P: 0.2618
# Episode: 507 Total reward: 46.0 Training loss: 33.1313 Explore P: 0.2606
# Episode: 508 Total reward: 15.0 Training loss: 140.2826 Explore P: 0.2602
# Episode: 509 Total reward: 179.0 Training loss: 1.7979 Explore P: 0.2558
# Episode: 510 Total reward: 61.0 Training loss: 1.2614 Explore P: 0.2543
# Episode: 511 Total reward: 113.0 Training loss: 1.9130 Explore P: 0.2516
# Episode: 512 Total reward: 57.0 Training loss: 2.1124 Explore P: 0.2502
# Episode: 513 Total reward: 62.0 Training loss: 40.9717 Explore P: 0.2487
# Episode: 514 Total reward: 55.0 Training loss: 67.6634 Explore P: 0.2474
# Episode: 515 Total reward: 61.0 Training loss: 1.2116 Explore P: 0.2459
# Episode: 516 Total reward: 97.0 Training loss: 0.9268 Explore P: 0.2437
# Episode: 517 Total reward: 94.0 Training loss: 48.2037 Explore P: 0.2415
# Episode: 518 Total reward: 47.0 Training loss: 1.1726 Explore P: 0.2404
# Episode: 519 Total reward: 64.0 Training loss: 1.1107 Explore P: 0.2389
# Episode: 520 Total reward: 49.0 Training loss: 1.1645 Explore P: 0.2378
# Episode: 521 Total reward: 72.0 Training loss: 63.8180 Explore P: 0.2362
# Episode: 522 Total reward: 53.0 Training loss: 0.9258 Explore P: 0.2350
# Episode: 523 Total reward: 62.0 Training loss: 138.9557 Explore P: 0.2336
# Episode: 524 Total reward: 43.0 Training loss: 2.0236 Explore P: 0.2326
# Episode: 525 Total reward: 50.0 Training loss: 1.2864 Explore P: 0.2315
# Episode: 526 Total reward: 69.0 Training loss: 236.8795 Explore P: 0.2300
# Episode: 527 Total reward: 68.0 Training loss: 2.7613 Explore P: 0.2285
# Episode: 528 Total reward: 92.0 Training loss: 0.6952 Explore P: 0.2265
# Episode: 529 Total reward: 57.0 Training loss: 89.9997 Explore P: 0.2253
# Episode: 530 Total reward: 74.0 Training loss: 189.4769 Explore P: 0.2237
# Episode: 531 Total reward: 145.0 Training loss: 2.0026 Explore P: 0.2206
# Episode: 532 Total reward: 76.0 Training loss: 37.1580 Explore P: 0.2190
# Episode: 533 Total reward: 97.0 Training loss: 32.5640 Explore P: 0.2170
# Episode: 534 Total reward: 77.0 Training loss: 41.4309 Explore P: 0.2154
# Episode: 535 Total reward: 70.0 Training loss: 2.1239 Explore P: 0.2140
# Episode: 536 Total reward: 92.0 Training loss: 1.0277 Explore P: 0.2121
# Episode: 537 Total reward: 199.0 Training loss: 1.8306 Explore P: 0.2081
# Episode: 538 Total reward: 199.0 Training loss: 43.8977 Explore P: 0.2042
# Episode: 539 Total reward: 94.0 Training loss: 1.0652 Explore P: 0.2024
# Episode: 540 Total reward: 98.0 Training loss: 0.9861 Explore P: 0.2005
# Episode: 541 Total reward: 79.0 Training loss: 35.1138 Explore P: 0.1990
# Episode: 542 Total reward: 81.0 Training loss: 1.5833 Explore P: 0.1975
# Episode: 543 Total reward: 68.0 Training loss: 1.0617 Explore P: 0.1962
# Episode: 544 Total reward: 87.0 Training loss: 1.5224 Explore P: 0.1946
# Episode: 545 Total reward: 137.0 Training loss: 1.8086 Explore P: 0.1921
# Episode: 546 Total reward: 53.0 Training loss: 2.3763 Explore P: 0.1911
# Episode: 547 Total reward: 67.0 Training loss: 1.0637 Explore P: 0.1899
# Episode: 548 Total reward: 105.0 Training loss: 1.0976 Explore P: 0.1881
# Episode: 549 Total reward: 59.0 Training loss: 1.5283 Explore P: 0.1870
# Episode: 550 Total reward: 49.0 Training loss: 1.5228 Explore P: 0.1861
# Episode: 551 Total reward: 50.0 Training loss: 2.6378 Explore P: 0.1853
# Episode: 552 Total reward: 46.0 Training loss: 1.2181 Explore P: 0.1845
# Episode: 553 Total reward: 50.0 Training loss: 1.2395 Explore P: 0.1836
# Episode: 554 Total reward: 79.0 Training loss: 36.3084 Explore P: 0.1822
# Episode: 555 Total reward: 56.0 Training loss: 1.7548 Explore P: 0.1813
# Episode: 556 Total reward: 62.0 Training loss: 0.8595 Explore P: 0.1802
# Episode: 557 Total reward: 87.0 Training loss: 2.2030 Explore P: 0.1787
# Episode: 558 Total reward: 64.0 Training loss: 1.1370 Explore P: 0.1777
# Episode: 559 Total reward: 84.0 Training loss: 154.9469 Explore P: 0.1763
# Episode: 560 Total reward: 58.0 Training loss: 1.5422 Explore P: 0.1753
# Episode: 561 Total reward: 158.0 Training loss: 2.1535 Explore P: 0.1727
# Episode: 562 Total reward: 140.0 Training loss: 32.8295 Explore P: 0.1704
# Episode: 563 Total reward: 142.0 Training loss: 1.4889 Explore P: 0.1682
# Episode: 564 Total reward: 199.0 Training loss: 2.1496 Explore P: 0.1651
# Episode: 565 Total reward: 199.0 Training loss: 88.7217 Explore P: 0.1620
# Episode: 566 Total reward: 128.0 Training loss: 118.3113 Explore P: 0.1601
# Episode: 567 Total reward: 161.0 Training loss: 81.6883 Explore P: 0.1577
# Episode: 568 Total reward: 114.0 Training loss: 1.1646 Explore P: 0.1560
# Episode: 569 Total reward: 96.0 Training loss: 1.5370 Explore P: 0.1546
# Episode: 570 Total reward: 114.0 Training loss: 1.9690 Explore P: 0.1530
# Episode: 571 Total reward: 62.0 Training loss: 2.0391 Explore P: 0.1521
# Episode: 572 Total reward: 68.0 Training loss: 1.4724 Explore P: 0.1511
# Episode: 573 Total reward: 95.0 Training loss: 135.5016 Explore P: 0.1498
# Episode: 574 Total reward: 86.0 Training loss: 2.0195 Explore P: 0.1486
# Episode: 575 Total reward: 101.0 Training loss: 119.3182 Explore P: 0.1472
# Episode: 576 Total reward: 155.0 Training loss: 174.1383 Explore P: 0.1451
# Episode: 577 Total reward: 84.0 Training loss: 79.4506 Explore P: 0.1440
# Episode: 578 Total reward: 152.0 Training loss: 1.5381 Explore P: 0.1419
# Episode: 579 Total reward: 199.0 Training loss: 0.9034 Explore P: 0.1393
# Episode: 580 Total reward: 132.0 Training loss: 1.4382 Explore P: 0.1376
# Episode: 581 Total reward: 176.0 Training loss: 0.8082 Explore P: 0.1354
# Episode: 582 Total reward: 142.0 Training loss: 75.8560 Explore P: 0.1336
# Episode: 583 Total reward: 199.0 Training loss: 1.5525 Explore P: 0.1312
# Episode: 584 Total reward: 165.0 Training loss: 2.0147 Explore P: 0.1292
# Episode: 585 Total reward: 118.0 Training loss: 247.0816 Explore P: 0.1278
# Episode: 586 Total reward: 178.0 Training loss: 1.2519 Explore P: 0.1257
# Episode: 587 Total reward: 102.0 Training loss: 0.3635 Explore P: 0.1246
# Episode: 588 Total reward: 69.0 Training loss: 0.6980 Explore P: 0.1238
# Episode: 589 Total reward: 199.0 Training loss: 2.0364 Explore P: 0.1215
# Episode: 590 Total reward: 199.0 Training loss: 0.4278 Explore P: 0.1193
# Episode: 591 Total reward: 113.0 Training loss: 2.2014 Explore P: 0.1181
# Episode: 592 Total reward: 199.0 Training loss: 0.5732 Explore P: 0.1160
# Episode: 593 Total reward: 199.0 Training loss: 33.6666 Explore P: 0.1139
# Episode: 594 Total reward: 143.0 Training loss: 0.4148 Explore P: 0.1124
# Episode: 595 Total reward: 199.0 Training loss: 1.0750 Explore P: 0.1104
# Episode: 596 Total reward: 199.0 Training loss: 0.4260 Explore P: 0.1084
# Episode: 597 Total reward: 199.0 Training loss: 21.8868 Explore P: 0.1065
# Episode: 598 Total reward: 151.0 Training loss: 0.3594 Explore P: 0.1050
# Episode: 599 Total reward: 199.0 Training loss: 0.6099 Explore P: 0.1032
# Episode: 600 Total reward: 199.0 Training loss: 0.7755 Explore P: 0.1013
# Episode: 601 Total reward: 199.0 Training loss: 36.8033 Explore P: 0.0995
# Episode: 602 Total reward: 199.0 Training loss: 0.2747 Explore P: 0.0978
# Episode: 603 Total reward: 162.0 Training loss: 0.3560 Explore P: 0.0964
# Episode: 604 Total reward: 175.0 Training loss: 0.5267 Explore P: 0.0949
# Episode: 605 Total reward: 119.0 Training loss: 1.7503 Explore P: 0.0939
# Episode: 606 Total reward: 86.0 Training loss: 1.4050 Explore P: 0.0931
# Episode: 607 Total reward: 103.0 Training loss: 11.7120 Explore P: 0.0923
# Episode: 608 Total reward: 76.0 Training loss: 0.5489 Explore P: 0.0917
# Episode: 609 Total reward: 78.0 Training loss: 0.2675 Explore P: 0.0910
# Episode: 610 Total reward: 141.0 Training loss: 0.9663 Explore P: 0.0899
# Episode: 611 Total reward: 194.0 Training loss: 0.2917 Explore P: 0.0884
# Episode: 612 Total reward: 168.0 Training loss: 0.3490 Explore P: 0.0871
# Episode: 613 Total reward: 199.0 Training loss: 0.2473 Explore P: 0.0855
# Episode: 614 Total reward: 150.0 Training loss: 1.9431 Explore P: 0.0844
# Episode: 615 Total reward: 169.0 Training loss: 0.6891 Explore P: 0.0832
# Episode: 616 Total reward: 129.0 Training loss: 1.6518 Explore P: 0.0822
# Episode: 617 Total reward: 199.0 Training loss: 0.3263 Explore P: 0.0808
# Episode: 618 Total reward: 185.0 Training loss: 0.2832 Explore P: 0.0795
# Episode: 619 Total reward: 199.0 Training loss: 0.1735 Explore P: 0.0781
# Episode: 620 Total reward: 199.0 Training loss: 0.9926 Explore P: 0.0768
# Episode: 621 Total reward: 199.0 Training loss: 0.2038 Explore P: 0.0755
# Episode: 622 Total reward: 199.0 Training loss: 28.9818 Explore P: 0.0742
# Episode: 623 Total reward: 199.0 Training loss: 0.2686 Explore P: 0.0729
# Episode: 624 Total reward: 199.0 Training loss: 0.2248 Explore P: 0.0717
# Episode: 625 Total reward: 199.0 Training loss: 223.9152 Explore P: 0.0705
# Episode: 626 Total reward: 199.0 Training loss: 25.1882 Explore P: 0.0693
# Episode: 627 Total reward: 199.0 Training loss: 0.4517 Explore P: 0.0681
# Episode: 628 Total reward: 199.0 Training loss: 0.2728 Explore P: 0.0670
# Episode: 629 Total reward: 199.0 Training loss: 0.1809 Explore P: 0.0658
# Episode: 630 Total reward: 199.0 Training loss: 0.2159 Explore P: 0.0647
# Episode: 631 Total reward: 199.0 Training loss: 0.5092 Explore P: 0.0637
# Episode: 632 Total reward: 199.0 Training loss: 31.6910 Explore P: 0.0626
# Episode: 633 Total reward: 199.0 Training loss: 0.1508 Explore P: 0.0616
# Episode: 634 Total reward: 199.0 Training loss: 0.1902 Explore P: 0.0606
# Episode: 635 Total reward: 199.0 Training loss: 0.2692 Explore P: 0.0596
# Episode: 636 Total reward: 199.0 Training loss: 0.3471 Explore P: 0.0586
# Episode: 637 Total reward: 199.0 Training loss: 0.2776 Explore P: 0.0576
# Episode: 638 Total reward: 199.0 Training loss: 0.4525 Explore P: 0.0567
# Episode: 639 Total reward: 199.0 Training loss: 0.2118 Explore P: 0.0558
# Episode: 640 Total reward: 199.0 Training loss: 0.1820 Explore P: 0.0549
# Episode: 641 Total reward: 199.0 Training loss: 0.3916 Explore P: 0.0540
# Episode: 642 Total reward: 199.0 Training loss: 55.0698 Explore P: 0.0531
# Episode: 643 Total reward: 199.0 Training loss: 0.2853 Explore P: 0.0523
# Episode: 644 Total reward: 199.0 Training loss: 0.2016 Explore P: 0.0514
# Episode: 645 Total reward: 199.0 Training loss: 0.1813 Explore P: 0.0506
# Episode: 646 Total reward: 199.0 Training loss: 0.2809 Explore P: 0.0498
# Episode: 647 Total reward: 199.0 Training loss: 0.3671 Explore P: 0.0490
# Episode: 648 Total reward: 199.0 Training loss: 0.4679 Explore P: 0.0483
# Episode: 649 Total reward: 199.0 Training loss: 0.2639 Explore P: 0.0475
# Episode: 650 Total reward: 199.0 Training loss: 0.3617 Explore P: 0.0468
# Episode: 651 Total reward: 199.0 Training loss: 0.0590 Explore P: 0.0460
# Episode: 652 Total reward: 199.0 Training loss: 0.3612 Explore P: 0.0453
# Episode: 653 Total reward: 199.0 Training loss: 0.2287 Explore P: 0.0446
# Episode: 654 Total reward: 199.0 Training loss: 0.1855 Explore P: 0.0440
# Episode: 655 Total reward: 199.0 Training loss: 0.2916 Explore P: 0.0433
# Episode: 656 Total reward: 199.0 Training loss: 314.4211 Explore P: 0.0426
# Episode: 657 Total reward: 199.0 Training loss: 0.2960 Explore P: 0.0420
# Episode: 658 Total reward: 199.0 Training loss: 0.2874 Explore P: 0.0414
# Episode: 659 Total reward: 199.0 Training loss: 0.2100 Explore P: 0.0407
# Episode: 660 Total reward: 199.0 Training loss: 0.4813 Explore P: 0.0401
# Episode: 661 Total reward: 199.0 Training loss: 0.3322 Explore P: 0.0395
# Episode: 662 Total reward: 199.0 Training loss: 0.1687 Explore P: 0.0390
# Episode: 663 Total reward: 199.0 Training loss: 0.2090 Explore P: 0.0384
# Episode: 664 Total reward: 199.0 Training loss: 516.7444 Explore P: 0.0378
# Episode: 665 Total reward: 199.0 Training loss: 0.5009 Explore P: 0.0373
# Episode: 666 Total reward: 199.0 Training loss: 0.1617 Explore P: 0.0367
# Episode: 667 Total reward: 199.0 Training loss: 0.1338 Explore P: 0.0362
# Episode: 668 Total reward: 199.0 Training loss: 0.1809 Explore P: 0.0357
# Episode: 669 Total reward: 199.0 Training loss: 0.3736 Explore P: 0.0352
# Episode: 670 Total reward: 199.0 Training loss: 0.3379 Explore P: 0.0347
# Episode: 671 Total reward: 199.0 Training loss: 0.1809 Explore P: 0.0342
# Episode: 672 Total reward: 199.0 Training loss: 0.1558 Explore P: 0.0337
# Episode: 673 Total reward: 199.0 Training loss: 0.3071 Explore P: 0.0333
# Episode: 674 Total reward: 199.0 Training loss: 0.1651 Explore P: 0.0328
# Episode: 675 Total reward: 199.0 Training loss: 0.2515 Explore P: 0.0324
# Episode: 676 Total reward: 199.0 Training loss: 0.2206 Explore P: 0.0319
# Episode: 677 Total reward: 199.0 Training loss: 0.2291 Explore P: 0.0315
# Episode: 678 Total reward: 199.0 Training loss: 0.1244 Explore P: 0.0311
# Episode: 679 Total reward: 199.0 Training loss: 0.1942 Explore P: 0.0306
# Episode: 680 Total reward: 199.0 Training loss: 0.2148 Explore P: 0.0302
# Episode: 681 Total reward: 199.0 Training loss: 0.2552 Explore P: 0.0298
# Episode: 682 Total reward: 199.0 Training loss: 0.2667 Explore P: 0.0294
# Episode: 683 Total reward: 199.0 Training loss: 0.2925 Explore P: 0.0291
# Episode: 684 Total reward: 199.0 Training loss: 0.3977 Explore P: 0.0287
# Episode: 685 Total reward: 199.0 Training loss: 0.4909 Explore P: 0.0283
# Episode: 686 Total reward: 199.0 Training loss: 0.2386 Explore P: 0.0280
# Episode: 687 Total reward: 199.0 Training loss: 0.1120 Explore P: 0.0276
# Episode: 688 Total reward: 199.0 Training loss: 0.2083 Explore P: 0.0273
# Episode: 689 Total reward: 199.0 Training loss: 250.1426 Explore P: 0.0269
# Episode: 690 Total reward: 199.0 Training loss: 0.2155 Explore P: 0.0266
# Episode: 691 Total reward: 199.0 Training loss: 276.2134 Explore P: 0.0263
# Episode: 692 Total reward: 199.0 Training loss: 0.2808 Explore P: 0.0259
# Episode: 693 Total reward: 199.0 Training loss: 0.4016 Explore P: 0.0256
# Episode: 694 Total reward: 199.0 Training loss: 0.5069 Explore P: 0.0253
# Episode: 695 Total reward: 199.0 Training loss: 0.5335 Explore P: 0.0250
# Episode: 696 Total reward: 199.0 Training loss: 265.9019 Explore P: 0.0247
# Episode: 697 Total reward: 199.0 Training loss: 0.3857 Explore P: 0.0244
# Episode: 698 Total reward: 199.0 Training loss: 0.4056 Explore P: 0.0241

# %% [markdown]
# ## Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, rews = np.array(rewards_list).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
test_episodes = 10
test_max_steps = 400
env.reset()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for ep in range(1, test_episodes):
        t = 0
        while t < test_max_steps:
            env.render() 
            
            # Get action from Q-network
            feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
            Qs = sess.run(mainQN.output, feed_dict=feed)
            action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
            
            if done:
                t = test_max_steps
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                state = next_state
                t += 1

# %%
env.close()

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
