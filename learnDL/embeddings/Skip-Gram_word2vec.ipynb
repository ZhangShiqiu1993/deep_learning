# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:12, 2.48MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freq = {word : count / total_count for word, count in word_counts.items() }
p_drop = {word : 1 - np.sqrt(threshold / freq[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    offset = np.random.randint(1, window_size + 1)
    start = idx - offset if (idx - offset) > 0 else 0
    stop = idx + offset
    target_words = set(words[start:idx] + words[idx + 1 : stop + 1])

    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6482 0.0323 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6140 0.0294 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4775 0.0295 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5776 0.0294 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5297 0.0293 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5029 0.0294 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5025 0.0294 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5333 0.0294 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4698 0.0293 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3991 0.0294 sec/batch
# Nearest to was: endorsing, ponty, chicagoland, averages, subtracting, rep, ashley, entailed,
# Nearest to no: iname, desertification, ithacan, pins, journeyed, impossibility, amidst, recoveries,
# Nearest to which: bosporus, vibrational, benenson, jaffna, ilr, anchor, pusan, pity,
# Nearest to states: politicians, warranties, catholic, classis, broadcasts, disclosed, calendrical, outranks,
# Nearest to up: jaina, larkin, likens, archaea, dvd, bibb, ahmednagar, responding,
# Nearest to a: pauli, inconsistencies, sabbath, postscript, spouse, pe, cad, cello,
# Nearest to united: nba, tom, snipers, accommodation, geezer, dvi, ratiocinator, patrons,
# Nearest to years: rz, abencerrages, strong, programmable, eurydice, vigilantes, overrode, bogus,
# Nearest to mean: millsaps, permanence, jasmine, gundestrup, representing, steinsaltz, masurian, ingrained,
# Nearest to placed: ranch, without, sami, funny, sister, current, nostra, bourdon,
# Nearest to pope: daisuke, binders, floresiensis, reconstruction, clubbing, takeda, lems, nabonidus,
# Nearest to question: luxemburg, lithograph, handguns, reactance, hitchhiker, compact, wadis, hesperides,
# Nearest to mainly: reemerged, matte, cooperation, monarchy, monopolization, emmylou, anglian, oxidation,
# Nearest to institute: charterers, contestants, kingsbridge, truncated, lsi, preparedness, canossa, ets,
# Nearest to animals: potok, antennae, andreini, asparagales, telemachus, chechnya, clearest, everton,
# Nearest to arts: gateway, gottfried, commute, treatable, akayev, ldf, philipp, stuttering,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4301 0.0305 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3803 0.0293 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3246 0.0294 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2336 0.0294 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1290 0.0293 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1585 0.0294 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0746 0.0294 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0501 0.0294 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0370 0.0294 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9965 0.0295 sec/batch
# Nearest to was: endorsing, averages, industry, various, rep, subtracting, chicagoland, remix,
# Nearest to no: pins, resolution, pulsed, waste, desertification, consistent, would, noticeable,
# Nearest to which: bosporus, matters, square, presents, vibrational, differs, serves, anchor,
# Nearest to states: politicians, catholic, broadcasts, differ, classis, warranties, outranks, disclosed,
# Nearest to up: dvd, males, responding, auditor, versions, decisive, convention, deep,
# Nearest to a: inconsistencies, spouse, pauli, reported, always, postscript, sabbath, another,
# Nearest to united: tom, nba, accommodation, snipers, patrons, dvi, calling, feathers,
# Nearest to years: rz, strong, abencerrages, varying, allowing, producing, lea, programmable,
# Nearest to mean: permanence, millsaps, always, representing, ramiro, loose, sparingly, post,
# Nearest to placed: without, ranch, current, funny, california, sister, sami, unity,
# Nearest to pope: reconstruction, binders, natural, daisuke, floresiensis, rectitude, framed, lems,
# Nearest to question: movement, papers, compact, render, hogs, memoirs, luxemburg, defections,
# Nearest to mainly: cooperation, negative, monarchy, matte, explain, reemerged, republican, combinations,
# Nearest to institute: charterers, kingsbridge, contestants, preparedness, consumers, chopin, sad, cleveland,
# Nearest to animals: potok, antennae, enlisted, telemachus, andreini, bisecting, acidic, reliance,
# Nearest to arts: gateway, refers, commute, gottfried, numeric, akayev, philipp, lockout,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9295 0.0304 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9039 0.0294 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8708 0.0294 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8462 0.0294 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8227 0.0294 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8229 0.0294 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7907 0.0295 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7643 0.0294 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7721 0.0294 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7667 0.0295 sec/batch
# Nearest to was: endorsing, lanka, averages, rep, remix, subtracting, venezuela, ashley,
# Nearest to no: desertification, waste, amidst, bacterial, pins, resolution, journeyed, impossibility,
# Nearest to which: presents, inversion, bosporus, vibrational, anchor, matters, benenson, square,
# Nearest to states: politicians, catholic, broadcasts, disclosed, classis, warranties, differ, solomon,
# Nearest to up: dvd, responding, decisive, auditor, inhabitants, versions, deep, males,
# Nearest to a: inconsistencies, pauli, spouse, resembled, pronouns, pe, cad, sabbath,
# Nearest to united: tom, accommodation, nba, snipers, calling, feathers, invest, ratiocinator,
# Nearest to years: rz, abencerrages, strong, programmable, varying, row, explorer, lea,
# Nearest to mean: representing, permanence, circumscribed, always, loose, ramiro, post, base,
# Nearest to placed: ranch, without, sami, current, funny, sister, california, vai,
# Nearest to pope: reconstruction, natural, binders, daisuke, rectitude, framed, foreign, lems,
# Nearest to question: papers, memoirs, luxemburg, compact, hogs, defections, movement, render,
# Nearest to mainly: cooperation, matte, republican, establishes, reemerged, adaptations, negative, explain,
# Nearest to institute: charterers, contestants, kingsbridge, preparedness, chopin, sad, truncated, cleveland,
# Nearest to animals: antennae, potok, telemachus, prejudice, enlisted, clearest, bisecting, andreini,
# Nearest to arts: gateway, commute, gottfried, formats, philipp, akayev, fahrenheit, lockout,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7750 0.0304 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7615 0.0295 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7324 0.0295 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7160 0.0294 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7383 0.0296 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6919 0.0293 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7403 0.0296 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7275 0.0292 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6740 0.0293 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6566 0.0292 sec/batch
# Nearest to was: endorsing, lanka, venezuela, ashley, rep, chicagoland, margaret, disregarded,
# Nearest to no: desertification, waste, amidst, consistent, inflow, bacterial, journeyed, ladino,
# Nearest to which: bosporus, presents, inversion, anchor, pity, jaffna, vibrational, pusan,
# Nearest to states: politicians, catholic, broadcasts, solomon, qatar, disclosed, classis, warranties,
# Nearest to up: dvd, responding, decisive, auditor, larkin, inhabitants, archaea, jaina,
# Nearest to a: inconsistencies, spouse, pauli, pe, resembled, pronouns, pitches, transcriptase,
# Nearest to united: nba, tom, accommodation, snipers, calling, feathers, national, ratiocinator,
# Nearest to years: rz, abencerrages, lea, steele, strong, bogus, explorer, programmable,
# Nearest to mean: representing, permanence, millsaps, jasmine, circumscribed, ramiro, always, loose,
# Nearest to placed: ranch, without, sami, current, funny, sister, contestant, seq,
# Nearest to pope: reconstruction, rectitude, daisuke, lems, natural, binders, th, floresiensis,
# Nearest to question: luxemburg, papers, hitchhiker, compact, memoirs, hogs, defections, memorabilia,
# Nearest to mainly: cooperation, matte, establishes, republican, reemerged, adaptations, dictatorship, emmylou,
# Nearest to institute: charterers, contestants, sad, kingsbridge, truncated, chopin, weidenfeld, diffeomorphism,
# Nearest to animals: antennae, potok, prejudice, telemachus, bisecting, clearest, enlisted, shining,
# Nearest to arts: gateway, commute, gottfried, philipp, akayev, formats, generalship, lockout,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6905 0.0303 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6671 0.0293 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6122 0.0295 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6189 0.0295 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6302 0.0293 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6258 0.0295 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5925 0.0219 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5219 0.0295 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5130 0.0295 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5049 0.0294 sec/batch
# Nearest to was: endorsing, lanka, disregarded, venezuela, belial, chicagoland, remix, subtracting,
# Nearest to no: desertification, inflow, pins, amidst, consistent, waste, ladino, boil,
# Nearest to which: presents, inversion, anchor, jaffna, bosporus, edema, ilr, ghat,
# Nearest to states: politicians, qatar, catholic, broadcasts, solomon, disclosed, invasion, territory,
# Nearest to up: responding, auditor, telekinesis, larkin, decisive, versions, depicts, dvd,
# Nearest to a: pauli, spouse, inconsistencies, pitches, argon, pronouns, tellings, bowling,
# Nearest to united: nba, tom, snipers, feathers, national, accommodation, calling, spectacled,
# Nearest to years: rz, lea, abencerrages, strong, steele, bogus, hickory, grainy,
# Nearest to mean: permanence, representing, circumscribed, ingrained, millsaps, loose, isobaric, always,
# Nearest to placed: ranch, without, sami, current, funny, contestant, nostra, turbo,
# Nearest to pope: b, reconstruction, rectitude, roman, th, normandie, lems, daisuke,
# Nearest to question: luxemburg, papers, hitchhiker, defections, reactance, lizzy, compact, memoirs,
# Nearest to mainly: cooperation, matte, establishes, republican, reemerged, triton, bridget, dictatorship,
# Nearest to institute: truncated, weidenfeld, contestants, charterers, kingsbridge, chopin, sad, berklee,
# Nearest to animals: antennae, potok, telemachus, prejudice, shining, refractive, clearest, bisecting,
# Nearest to arts: gateway, gottfried, akayev, commute, sharks, formats, treatable, kropotkin,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5013 0.0305 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4878 0.0294 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4517 0.0295 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5067 0.0295 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4960 0.0294 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4966 0.0294 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4677 0.0294 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3988 0.0294 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4437 0.0294 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4183 0.0293 sec/batch
# Nearest to was: endorsing, disregarded, attend, lanka, chicagoland, belial, remix, serving,
# Nearest to no: consistent, desertification, waste, resolution, amidst, ladino, journeyed, boil,
# Nearest to which: inversion, presents, anchor, jaffna, bosporus, ilr, ghat, edema,
# Nearest to states: politicians, qatar, solomon, territory, foreign, broadcasts, disclosed, invasion,
# Nearest to up: responding, versions, decisive, auditor, telekinesis, dvd, larkin, jaina,
# Nearest to a: inconsistencies, tellings, cad, pauli, only, argon, pitches, spouse,
# Nearest to united: national, nba, snipers, accommodation, tom, calling, feathers, spectacled,
# Nearest to years: rz, abencerrages, lea, strong, steele, grainy, female, lives,
# Nearest to mean: permanence, isobaric, always, circumscribed, representing, millsaps, jasmine, ingrained,
# Nearest to placed: ranch, without, current, funny, sami, contestant, bildungsroman, nkomo,
# Nearest to pope: roman, rectitude, th, normandie, b, daisuke, reconstruction, lems,
# Nearest to question: hitchhiker, luxemburg, papers, reactance, defections, memoirs, lizzy, resemblance,
# Nearest to mainly: cooperation, matte, establishes, bridget, bulk, reemerged, republican, emmylou,
# Nearest to institute: weidenfeld, bernstein, cleveland, chopin, usmc, diffeomorphism, contestants, truncated,
# Nearest to animals: antennae, telemachus, acidic, bisecting, potok, prejudice, refractive, shining,
# Nearest to arts: gateway, gottfried, akayev, commute, sharks, lockout, subterfuge, substitutions,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4451 0.0306 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4257 0.0293 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4240 0.0294 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4062 0.0295 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4126 0.0295 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4346 0.0294 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3832 0.0293 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4053 0.0293 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4401 0.0293 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3726 0.0296 sec/batch
# Nearest to was: endorsing, remix, disregarded, chicagoland, belial, attend, entailed, capri,
# Nearest to no: amidst, consistent, resolution, waste, ladino, would, boil, be,
# Nearest to which: presents, inversion, vibrational, ilr, jaffna, csound, ghat, anchor,
# Nearest to states: politicians, qatar, solomon, foreign, brokerage, broadcasts, territory, classis,
# Nearest to up: responding, versions, auditor, jaina, decisive, larkin, deep, telekinesis,
# Nearest to a: inconsistencies, argon, tellings, pitches, pauli, cad, only, spouse,
# Nearest to united: national, nba, snipers, foreign, accommodation, tom, calling, russia,
# Nearest to years: rz, lea, abencerrages, female, preproduction, strong, lives, steele,
# Nearest to mean: permanence, isobaric, always, circumscribed, jasmine, representing, millsaps, approx,
# Nearest to placed: without, ranch, current, funny, nkomo, bildungsroman, contestant, vai,
# Nearest to pope: roman, rectitude, normandie, th, daisuke, methodist, takeda, lems,
# Nearest to question: memoirs, hitchhiker, luxemburg, papers, lizzy, reactance, resemblance, render,
# Nearest to mainly: cooperation, matte, establishes, bulk, emmylou, irrigated, triton, morphological,
# Nearest to institute: weidenfeld, usmc, bernstein, chopin, freire, berklee, cleveland, habitations,
# Nearest to animals: antennae, telemachus, acidic, bisecting, prejudice, refractive, clearest, reliance,
# Nearest to arts: gateway, gottfried, akayev, sharks, commute, subterfuge, stuttering, ablation,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3912 0.0304 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3932 0.0294 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3685 0.0294 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3629 0.0295 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3763 0.0295 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3718 0.0295 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3888 0.0295 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3882 0.0294 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3284 0.0295 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3163 0.0292 sec/batch
# Nearest to was: endorsing, disregarded, were, chicagoland, belial, captives, attend, capri,
# Nearest to no: consistent, amidst, would, be, ladino, resolution, possibilities, desertification,
# Nearest to which: vibrational, ghat, inversion, presents, csound, ilr, buridan, bosporus,
# Nearest to states: qatar, politicians, foreign, brokerage, disclosed, territory, solomon, restraints,
# Nearest to up: responding, auditor, jaina, pm, versions, deep, steady, decisive,
# Nearest to a: argon, pitches, inconsistencies, always, tellings, biathlon, gre, spouse,
# Nearest to united: national, nba, foreign, snipers, calling, russia, spectacled, geezer,
# Nearest to years: rz, female, lea, abencerrages, preproduction, lives, strong, rate,
# Nearest to mean: always, isobaric, approx, circumscribed, ingrained, jasmine, permanence, denotes,
# Nearest to placed: without, ranch, funny, current, nkomo, vai, bildungsroman, contestant,
# Nearest to pope: roman, daisuke, rectitude, th, normandie, lems, takeda, nubia,
# Nearest to question: memoirs, luxemburg, defections, lizzy, papers, hitchhiker, informed, movement,
# Nearest to mainly: cooperation, matte, morphological, bulk, establishes, grown, weakness, dictatorship,
# Nearest to institute: weidenfeld, usmc, bernstein, education, cleveland, captained, freire, inspection,
# Nearest to animals: antennae, telemachus, acidic, clearest, dogs, prejudice, bisecting, shining,
# Nearest to arts: gateway, gottfried, akayev, sharks, subterfuge, lockout, commute, ablation,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3422 0.0305 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2981 0.0296 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3486 0.0295 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3704 0.0293 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3963 0.0295 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2890 0.0294 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2924 0.0292 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3499 0.0295 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2071 0.0293 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3051 0.0295 sec/batch
# Nearest to was: endorsing, disregarded, chicagoland, were, archiepiscopal, capri, incantations, belial,
# Nearest to no: consistent, be, amidst, would, possibilities, boil, desertification, ladino,
# Nearest to which: csound, ghat, presents, serves, vibrational, bosporus, pusan, ilr,
# Nearest to states: politicians, qatar, foreign, brokerage, restraints, disclosed, territory, solomon,
# Nearest to up: responding, decisive, pm, crux, larkin, cohorts, auditor, versions,
# Nearest to a: argon, always, cad, inconsistencies, gre, ordinates, tellings, bowling,
# Nearest to united: nba, foreign, national, calling, snipers, geezer, spectacled, tom,
# Nearest to years: female, male, lea, rz, rate, births, migrant, preproduction,
# Nearest to mean: always, approx, isobaric, denotes, jasmine, millsaps, representing, ingrained,
# Nearest to placed: without, ranch, funny, current, vai, bildungsroman, seq, nkomo,
# Nearest to pope: daisuke, b, rectitude, roman, th, paolo, normandie, lems,
# Nearest to question: memoirs, lizzy, render, defections, luxemburg, livebearers, genitive, informed,
# Nearest to mainly: cooperation, matte, bulk, morphological, establishes, grown, irredentism, sardinian,
# Nearest to institute: education, usmc, weidenfeld, inspection, universities, bernstein, focuses, school,
# Nearest to animals: antennae, acidic, telemachus, dogs, clearest, shining, prejudice, bisecting,
# Nearest to arts: gateway, akayev, gottfried, hingle, sharks, ablation, acronym, phrygian,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2994 0.0305 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3227 0.0294 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3177 0.0141 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2452 0.0295 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2239 0.0294 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2449 0.0296 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2149 0.0294 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2463 0.0294 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2251 0.0294 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1992 0.0293 sec/batch
# Nearest to was: endorsing, capri, were, incantations, archiepiscopal, disregarded, chicagoland, regal,
# Nearest to no: amidst, would, be, consistent, boil, desertification, possibilities, ladino,
# Nearest to which: csound, ghat, vibrational, anchor, bosporus, presents, pusan, sheilding,
# Nearest to states: qatar, politicians, brokerage, territory, foreign, restraints, warranties, disclosed,
# Nearest to up: deep, decisive, crux, pm, cohorts, auditor, steady, responding,
# Nearest to a: argon, tellings, always, gre, pe, pitches, cad, biathlon,
# Nearest to united: nba, national, spectacled, foreign, geezer, snipers, calling, authorized,
# Nearest to years: female, male, abencerrages, rz, births, lea, preproduction, migrant,
# Nearest to mean: approx, ingrained, denotes, always, millsaps, jasmine, isobaric, steinsaltz,
# Nearest to placed: without, ranch, funny, current, sister, bildungsroman, nkomo, vai,
# Nearest to pope: roman, daisuke, rectitude, b, gregory, th, paolo, pauline,
# Nearest to question: memoirs, render, defections, lizzy, liking, genitive, livebearers, specifier,
# Nearest to mainly: matte, cooperation, bulk, morphological, grown, establishes, hydrocarbons, irredentism,
# Nearest to institute: education, usmc, universities, inspection, weidenfeld, vocational, school, focuses,
# Nearest to animals: antennae, acidic, telemachus, dogs, prejudice, shining, clearest, andreini,
# Nearest to arts: gateway, gottfried, akayev, hingle, sharks, phrygian, subterfuge, acronym,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2436 0.0305 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2039 0.0292 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2574 0.0294 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1334 0.0293 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1823 0.0295 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1457 0.0295 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1801 0.0296 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1808 0.0294 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1898 0.0295 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1570 0.0295 sec/batch
# Nearest to was: endorsing, incantations, were, capri, disregarded, regal, archiepiscopal, chicagoland,
# Nearest to no: be, would, amidst, consistent, possibilities, boil, resolution, caver,
# Nearest to which: csound, ghat, vibrational, serves, anchor, sheilding, seriousness, presents,
# Nearest to states: qatar, politicians, brokerage, disclosed, warranties, restraints, pamplona, homeschooling,
# Nearest to up: deep, pm, decisive, versions, cohorts, responding, steady, auditor,
# Nearest to a: argon, always, ordinates, biathlon, another, inconsistencies, pauli, cad,
# Nearest to united: national, nba, foreign, geezer, spectacled, calling, authorized, snipers,
# Nearest to years: female, male, abencerrages, rz, migrant, preproduction, lives, rate,
# Nearest to mean: denotes, ingrained, jasmine, always, approx, millsaps, steinsaltz, isobaric,
# Nearest to placed: without, ranch, funny, bildungsroman, sister, current, vai, tagged,
# Nearest to pope: daisuke, gregory, rectitude, roman, paolo, pauline, lems, krugman,
# Nearest to question: memoirs, render, defections, nosebleed, genitive, lizzy, visegr, papers,
# Nearest to mainly: matte, cooperation, morphological, bulk, grown, hydrocarbons, triton, particularly,
# Nearest to institute: education, universities, school, vocational, usmc, bernstein, university, inspection,
# Nearest to animals: antennae, acidic, telemachus, dogs, prejudice, clearest, shining, andreini,
# Nearest to arts: gateway, gottfried, akayev, sharks, hingle, colleges, subterfuge, urbana,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1864 0.0305 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2532 0.0296 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1813 0.0294 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1570 0.0295 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1887 0.0293 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1892 0.0294 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1842 0.0294 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1774 0.0295 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1381 0.0293 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1674 0.0294 sec/batch
# Nearest to was: endorsing, incantations, capri, were, archiepiscopal, regal, chicagoland, leniency,
# Nearest to no: be, amidst, would, boil, possibilities, resolution, pins, ladino,
# Nearest to which: vibrational, csound, ghat, inversion, sheilding, presents, anchor, serves,
# Nearest to states: politicians, qatar, brokerage, classis, restraints, disclosed, warranties, homeschooling,
# Nearest to up: decisive, deep, responding, pm, cohorts, dvd, auditor, proscribed,
# Nearest to a: argon, always, biathlon, pauli, pitches, bowling, inconsistencies, probed,
# Nearest to united: nba, national, geezer, foreign, spee, articles, calling, authorized,
# Nearest to years: male, female, migrant, rate, preproduction, rz, abencerrages, expectancy,
# Nearest to mean: ingrained, always, denotes, millsaps, jasmine, steinsaltz, cocking, naturalisation,
# Nearest to placed: without, ranch, funny, sister, current, bildungsroman, vai, sideline,
# Nearest to pope: gregory, daisuke, b, paolo, roman, rectitude, pauline, lems,
# Nearest to question: memoirs, defections, genitive, nosebleed, lizzy, render, augsburg, visegr,
# Nearest to mainly: matte, morphological, grown, cooperation, bulk, dictatorship, irredentism, hydrocarbons,
# Nearest to institute: education, universities, vocational, school, usmc, bernstein, engineering, inspection,
# Nearest to animals: antennae, acidic, telemachus, dogs, clearest, prejudice, shining, avian,
# Nearest to arts: gateway, akayev, gottfried, hingle, sharks, acronym, subterfuge, colleges,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1892 0.0306 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1975 0.0296 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2170 0.0293 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2029 0.0294 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1683 0.0294 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1251 0.0294 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1570 0.0296 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1450 0.0294 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1609 0.0295 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2041 0.0294 sec/batch
# Nearest to was: were, endorsing, incantations, by, capri, had, archiepiscopal, fierce,
# Nearest to no: be, amidst, would, possibilities, boil, ladino, resolution, fubar,
# Nearest to which: csound, vibrational, ghat, serves, sheilding, matters, buridan, presents,
# Nearest to states: politicians, qatar, restraints, warranties, brokerage, pamplona, classis, disclosed,
# Nearest to up: pm, deep, responding, cohorts, decisive, dvd, proscribed, steady,
# Nearest to a: always, bowling, biathlon, argon, diana, as, owain, lemnian,
# Nearest to united: nba, geezer, spee, national, articles, foreign, authorized, susilo,
# Nearest to years: male, female, rate, migrant, expectancy, preproduction, abencerrages, births,
# Nearest to mean: ingrained, always, denotes, jasmine, approx, cocking, representing, circumscribed,
# Nearest to placed: without, ranch, funny, sister, bildungsroman, sideline, vai, nessus,
# Nearest to pope: gregory, b, daisuke, paolo, krugman, rectitude, pauline, roman,
# Nearest to question: memoirs, augsburg, defections, genitive, nosebleed, visegr, fannie, render,
# Nearest to mainly: matte, morphological, grown, irredentism, bulk, sardinian, dictatorship, particularly,
# Nearest to institute: education, universities, vocational, school, sciences, bernstein, engineering, usmc,
# Nearest to animals: antennae, dogs, acidic, telemachus, prejudice, clearest, shining, ingots,
# Nearest to arts: hingle, colleges, gateway, akayev, subterfuge, gottfried, acronym, urbana,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2242 0.0305 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1411 0.0293 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1293 0.0293 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1490 0.0293 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0455 0.0295 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1456 0.0295 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1290 0.0295 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1344 0.0295 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1848 0.0061 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1214 0.0295 sec/batch
# Nearest to was: were, incantations, endorsing, by, capri, regal, industry, disregarded,
# Nearest to no: amidst, be, would, boil, possibilities, fubar, ladino, consistent,
# Nearest to which: vibrational, csound, serves, sheilding, presents, ghat, anchor, limitless,
# Nearest to states: qatar, politicians, restraints, brokerage, territory, pamplona, catholic, warranties,
# Nearest to up: deep, steady, pm, proscribed, cohorts, decisive, beams, dvd,
# Nearest to a: as, always, argon, bowling, pitches, controllable, for, biathlon,
# Nearest to united: geezer, nba, spee, national, authorized, foreign, articles, spectacled,
# Nearest to years: male, female, rate, migrant, expectancy, births, birth, four,
# Nearest to mean: always, denotes, cocking, ingrained, permutations, representing, approx, isobaric,
# Nearest to placed: without, ranch, funny, sister, sideline, nessus, plated, bildungsroman,
# Nearest to pope: gregory, b, daisuke, paolo, krugman, rectitude, glaswegians, pauline,
# Nearest to question: memoirs, augsburg, nosebleed, genitive, defections, visegr, lande, render,
# Nearest to mainly: matte, morphological, grown, bulk, particularly, irredentism, hydrocarbons, seafood,
# Nearest to institute: education, universities, vocational, sciences, engineering, school, university, bernstein,
# Nearest to animals: antennae, dogs, acidic, telemachus, prejudice, shining, clearest, struggling,
# Nearest to arts: colleges, hingle, subterfuge, akayev, studied, universities, gateway, bz,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0926 0.0305 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0526 0.0295 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0880 0.0295 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0631 0.0294 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0720 0.0294 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0503 0.0293 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0902 0.0293 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0986 0.0296 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1510 0.0294 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0402 0.0294 sec/batch
# Nearest to was: were, by, had, incantations, capri, disregarded, fierce, endorsing,
# Nearest to no: would, be, amidst, boil, possibilities, caver, resolution, waste,
# Nearest to which: vibrational, serves, sheilding, csound, ghat, holding, intervenes, rifling,
# Nearest to states: qatar, politicians, warranties, pamplona, homeschooling, brokerage, restraints, catholic,
# Nearest to up: deep, proscribed, cohorts, decisive, pm, steady, depicts, crux,
# Nearest to a: as, always, argon, of, the, biathlon, only, controllable,
# Nearest to united: national, plotdata, nba, geezer, foreign, spee, articles, authorized,
# Nearest to years: male, female, rate, migrant, expectancy, four, births, householder,
# Nearest to mean: always, cocking, denotes, ingrained, representing, permutations, approx, steinsaltz,
# Nearest to placed: without, ranch, sister, funny, plated, sideline, bildungsroman, nessus,
# Nearest to pope: gregory, paolo, daisuke, b, krugman, rectitude, pauline, roman,
# Nearest to question: memoirs, defections, nosebleed, augsburg, visegr, genitive, lande, render,
# Nearest to mainly: matte, morphological, bulk, grown, particularly, hydrocarbons, irredentism, dictatorship,
# Nearest to institute: education, vocational, engineering, universities, sciences, school, university, bernstein,
# Nearest to animals: antennae, dogs, prejudice, acidic, telemachus, struggling, herbivorous, footed,
# Nearest to arts: colleges, diwali, universities, akayev, subterfuge, gottfried, bz, gateway,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0188 0.0306 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0385 0.0294 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0104 0.0294 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0546 0.0294 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0532 0.0294 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0589 0.0295 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0708 0.0295 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1158 0.0293 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0541 0.0293 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0494 0.0293 sec/batch
# Nearest to was: were, had, by, capri, incantations, endorsing, regal, disregarded,
# Nearest to no: be, would, boil, amidst, proteomics, consistent, aftermarket, noticeable,
# Nearest to which: vibrational, serves, csound, sheilding, lifeforms, anchor, of, ghat,
# Nearest to states: qatar, politicians, warranties, homeschooling, catholic, pamplona, restraints, brokerage,
# Nearest to up: proscribed, deep, cohorts, pm, steady, dvd, decisive, triangular,
# Nearest to a: always, as, the, stitch, argon, for, of, biathlon,
# Nearest to united: national, articles, spee, geezer, authorized, foreign, nba, plotdata,
# Nearest to years: male, female, migrant, rate, expectancy, four, five, births,
# Nearest to mean: always, ingrained, cocking, representing, approx, steinsaltz, denotes, naturalisation,
# Nearest to placed: without, ranch, sister, funny, plated, scoring, bildungsroman, sideline,
# Nearest to pope: gregory, daisuke, paolo, b, krugman, papacy, xii, rectitude,
# Nearest to question: memoirs, genitive, nosebleed, visegr, lande, defections, augsburg, render,
# Nearest to mainly: morphological, matte, grown, particularly, hydrocarbons, irredentism, bulk, faroese,
# Nearest to institute: education, vocational, universities, engineering, sciences, school, university, weidenfeld,
# Nearest to animals: antennae, dogs, prejudice, acidic, herbivorous, telemachus, footed, struggling,
# Nearest to arts: colleges, universities, hingle, diwali, akayev, bz, gottfried, subterfuge,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0537 0.0304 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0782 0.0295 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0548 0.0295 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0753 0.0293 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0585 0.0295 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0500 0.0295 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0820 0.0293 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0525 0.0296 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1053 0.0295 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0560 0.0294 sec/batch
# Nearest to was: by, had, were, his, capri, raiding, stadtholder, incantations,
# Nearest to no: be, would, boil, amidst, rabin, pins, waste, prefixing,
# Nearest to which: vibrational, serves, csound, sheilding, schism, conceding, matters, of,
# Nearest to states: qatar, politicians, warranties, pamplona, homeschooling, restraints, brokerage, catholic,
# Nearest to up: proscribed, deep, cohorts, decisive, pm, steady, auditor, fates,
# Nearest to a: always, as, biathlon, another, preserves, for, stitch, of,
# Nearest to united: spee, nba, articles, national, geezer, authorized, kingdom, kaiserliche,
# Nearest to years: male, migrant, female, expectancy, rate, four, five, birth,
# Nearest to mean: always, representing, ingrained, cocking, isobaric, approx, denotes, steinsaltz,
# Nearest to placed: without, ranch, sister, plated, scoring, funny, sideline, bildungsroman,
# Nearest to pope: gregory, daisuke, b, paolo, krugman, papacy, rectitude, roman,
# Nearest to question: memoirs, defections, genitive, nosebleed, augsburg, visegr, fannie, lande,
# Nearest to mainly: morphological, matte, grown, faroese, irredentism, bulk, particularly, dictatorship,
# Nearest to institute: education, vocational, universities, engineering, sciences, school, university, weidenfeld,
# Nearest to animals: antennae, dogs, prejudice, herbivorous, footed, acidic, telemachus, wiping,
# Nearest to arts: colleges, hingle, diwali, akayev, universities, bz, subterfuge, gateway,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0635 0.0304 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0177 0.0293 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0277 0.0293 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0745 0.0296 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0581 0.0296 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1278 0.0293 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1340 0.0294 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0542 0.0293 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0294 0.0293 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0544 0.0292 sec/batch
# Nearest to was: by, had, were, capri, incantations, regal, leniency, his,
# Nearest to no: would, be, boil, pins, amidst, subsistence, consistent, waste,
# Nearest to which: serves, vibrational, csound, holding, havre, sheilding, limitless, anchor,
# Nearest to states: qatar, politicians, pamplona, solomon, territory, warranties, restraints, homeschooling,
# Nearest to up: proscribed, pm, deep, cohorts, steady, imperfective, decisive, dvd,
# Nearest to a: as, biathlon, always, another, controllable, for, preserves, and,
# Nearest to united: spee, nba, geezer, authorized, articles, kaiserliche, molesworth, plotdata,
# Nearest to years: male, migrant, female, expectancy, rate, four, year, five,
# Nearest to mean: representing, ingrained, always, cocking, approx, jasmine, isobaric, steinsaltz,
# Nearest to placed: without, ranch, sister, funny, plated, sideline, scoring, nessus,
# Nearest to pope: gregory, daisuke, b, paolo, krugman, papacy, xii, rectitude,
# Nearest to question: memoirs, visegr, nosebleed, augsburg, genitive, fannie, defections, answer,
# Nearest to mainly: morphological, matte, grown, faroese, irredentism, bulk, lorenzo, dictatorship,
# Nearest to institute: education, universities, vocational, engineering, sciences, school, weidenfeld, berklee,
# Nearest to animals: antennae, dogs, prejudice, herbivorous, footed, acidic, interbreeding, wiping,
# Nearest to arts: colleges, hingle, diwali, universities, bz, akayev, academics, academies,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9833 0.0304 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0146 0.0294 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0400 0.0296 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0381 0.0294 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0873 0.0293 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0517 0.0275 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0391 0.0294 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9772 0.0293 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0013 0.0294 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9718 0.0294 sec/batch
# Nearest to was: by, were, had, incantations, capri, regal, disregarded, leniency,
# Nearest to no: be, would, boil, amidst, waste, journeyed, pins, desertification,
# Nearest to which: anchor, vibrational, serves, csound, listerine, holding, ghat, lifeforms,
# Nearest to states: qatar, politicians, territory, bales, warranties, pamplona, u, restraints,
# Nearest to up: proscribed, cohorts, deep, imperfective, steady, pm, crux, fates,
# Nearest to a: as, biathlon, for, the, probed, always, another, of,
# Nearest to united: spee, kaiserliche, authorized, geezer, plotdata, articles, materialise, nba,
# Nearest to years: male, migrant, female, expectancy, rate, four, five, birth,
# Nearest to mean: cocking, ingrained, always, representing, naturalisation, steinsaltz, jasmine, masurian,
# Nearest to placed: without, ranch, sister, plated, scoring, sideline, funny, bildungsroman,
# Nearest to pope: gregory, daisuke, b, paolo, krugman, papacy, antipope, rectitude,
# Nearest to question: memoirs, visegr, nosebleed, defections, augsburg, fannie, genitive, answer,
# Nearest to mainly: morphological, matte, grown, bulk, hydrocarbons, sulfides, particularly, irredentism,
# Nearest to institute: education, universities, engineering, vocational, sciences, weidenfeld, educated, technology,
# Nearest to animals: antennae, dogs, footed, prejudice, herbivorous, wiping, asparagales, interbreeding,
# Nearest to arts: colleges, hingle, bz, diwali, universities, thai, subterfuge, exhibitions,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9976 0.0305 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9384 0.0295 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0353 0.0294 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0098 0.0295 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0383 0.0295 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0233 0.0295 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9388 0.0295 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9368 0.0294 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9122 0.0296 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9578 0.0294 sec/batch
# Nearest to was: had, by, were, capri, incantations, his, magister, leniency,
# Nearest to no: be, would, boil, caver, waste, desertification, pins, proteomics,
# Nearest to which: vibrational, serves, holding, of, anchor, listerine, rnas, rifling,
# Nearest to states: qatar, politicians, warranties, bales, pamplona, prokaryotes, u, territory,
# Nearest to up: deep, proscribed, pm, cohorts, imperfective, is, steady, stand,
# Nearest to a: as, always, the, for, another, of, probed, preserves,
# Nearest to united: plotdata, authorized, geezer, articles, spee, origin, kaiserliche, kingdom,
# Nearest to years: male, migrant, female, expectancy, four, rate, five, year,
# Nearest to mean: cocking, always, naturalisation, ingrained, size, masurian, jasmine, isobaric,
# Nearest to placed: without, ranch, sister, plated, scoring, sideline, funny, nessus,
# Nearest to pope: gregory, daisuke, paolo, b, krugman, rectitude, antipope, papacy,
# Nearest to question: memoirs, nosebleed, visegr, genitive, answer, augsburg, defections, fannie,
# Nearest to mainly: morphological, matte, grown, sulfides, particularly, faroese, irredentism, dispenses,
# Nearest to institute: education, universities, vocational, university, engineering, sciences, technology, school,
# Nearest to animals: antennae, dogs, prejudice, footed, interbreeding, herbivorous, pseudomonas, asparagales,
# Nearest to arts: colleges, universities, academies, gallery, hingle, bz, diwali, urbana,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0196 0.0304 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9883 0.0294 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9759 0.0293 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0035 0.0293 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0457 0.0295 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9651 0.0294 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0381 0.0294 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9948 0.0295 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0075 0.0294 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0141 0.0294 sec/batch
# Nearest to was: had, by, were, capri, his, incantations, leniency, prerogative,
# Nearest to no: waste, would, be, caver, prefixing, pins, desertification, boil,
# Nearest to which: vibrational, serves, holding, listerine, anchor, of, anachronisms, sheilding,
# Nearest to states: qatar, politicians, warranties, u, territory, prokaryotes, restraints, bales,
# Nearest to up: proscribed, cohorts, dvd, auditor, kay, deep, yearning, pm,
# Nearest to a: as, for, another, always, the, probed, and, stitch,
# Nearest to united: spee, kingdom, kaiserliche, origin, plotdata, geezer, smyth, articles,
# Nearest to years: migrant, male, female, expectancy, year, five, four, rate,
# Nearest to mean: cocking, naturalisation, ingrained, always, steinsaltz, masurian, skaters, jasmine,
# Nearest to placed: without, scoring, sister, ranch, plated, sideline, current, funny,
# Nearest to pope: gregory, daisuke, b, paolo, krugman, papacy, antipope, rectitude,
# Nearest to question: memoirs, visegr, nosebleed, augsburg, genitive, answer, fannie, defections,
# Nearest to mainly: morphological, matte, grown, faroese, sulfides, safi, regained, huguenots,
# Nearest to institute: education, universities, vocational, engineering, sciences, university, school, technology,
# Nearest to animals: antennae, dogs, footed, prejudice, interbreeding, herbivorous, wiping, pseudomonas,
# Nearest to arts: colleges, gallery, academies, universities, exhibitions, hingle, diwali, urbana,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0190 0.0305 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9783 0.0293 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9742 0.0293 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9922 0.0293 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0213 0.0295 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9937 0.0292 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9865 0.0294 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9579 0.0295 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9773 0.0294 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0183 0.0296 sec/batch
# Nearest to was: had, by, were, his, capri, raiding, fierce, prerogative,
# Nearest to no: would, be, waste, caver, prefixing, desertification, abdicated, boil,
# Nearest to which: vibrational, holding, serves, of, in, it, buridan, kingdom,
# Nearest to states: qatar, politicians, u, warranties, territory, prokaryotes, solomon, restraints,
# Nearest to up: proscribed, imperfective, dvd, deep, steady, cohorts, pm, kay,
# Nearest to a: as, for, the, always, and, another, probed, of,
# Nearest to united: kingdom, spee, kaiserliche, authorized, states, smyth, origin, plotdata,
# Nearest to years: migrant, male, female, expectancy, year, rate, four, birth,
# Nearest to mean: always, cocking, naturalisation, ingrained, isobaric, minima, skaters, steinsaltz,
# Nearest to placed: without, sister, scoring, plated, ranch, sideline, funny, nessus,
# Nearest to pope: gregory, daisuke, b, krugman, paolo, papacy, antipope, rectitude,
# Nearest to question: memoirs, nosebleed, visegr, answer, augsburg, genitive, fannie, defections,
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8990 0.0293 sec/batch
# Nearest to was: had, by, were, became, in, as, later, the,
# Nearest to no: would, comoros, waste, one, be, that, dnieper, caver,
# Nearest to which: in, a, by, of, and, the, is, original,
# Nearest to states: united, u, politicians, confederacy, perdido, classis, warranties, qatar,
# Nearest to up: yearning, slipped, changing, keep, back, stand, drysdale, lons,
# Nearest to a: as, of, the, and, in, for, is, by,
# Nearest to united: states, kingdom, morley, origin, baptism, molesworth, kaiserliche, curtail,
# Nearest to years: five, migrant, male, year, female, four, births, expectancy,
# Nearest to mean: cocking, average, steinsaltz, hottest, averages, wag, arithmetic, naturalisation,
# Nearest to placed: without, plated, scoring, gareth, carthusian, drawn, current, telnet,
# Nearest to pope: gregory, papacy, antipope, sixtus, daisuke, lateran, bolden, kinross,
# Nearest to question: answer, whether, memoirs, visegr, augsburg, surfacing, cliffe, genitive,
# Nearest to mainly: regained, many, morphological, bahamut, and, manco, ast, their,
# Nearest to institute: education, technology, berklee, phoned, inspection, cleveland, dieter, sciences,
# Nearest to animals: dogs, interbreeding, asparagales, footed, antennae, canids, mesoplodon, prejudice,
# Nearest to arts: martial, muay, thai, examinations, gallery, academies, jitsu, intricate,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8235 0.0305 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8749 0.0294 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8590 0.0293 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8466 0.0295 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8801 0.0293 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8683 0.0295 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8536 0.0293 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8489 0.0294 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8904 0.0294 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8633 0.0295 sec/batch
# Nearest to was: had, by, were, became, in, later, as, the,
# Nearest to no: comoros, would, waste, one, abdicated, imperative, that, only,
# Nearest to which: in, by, of, a, and, the, is, original,
# Nearest to states: united, u, politicians, confederacy, perdido, warranties, qatar, geographic,
# Nearest to up: yearning, changing, slipped, keep, lons, franks, stand, drysdale,
# Nearest to a: of, as, and, in, the, for, is, also,
# Nearest to united: states, kingdom, russia, kaiserliche, spee, molesworth, morley, tuva,
# Nearest to years: five, migrant, male, female, four, year, expectancy, births,
# Nearest to mean: cocking, arithmetic, average, hottest, steinsaltz, minima, averages, cubans,
# Nearest to placed: without, plated, scoring, gareth, carthusian, drawn, nessus, current,
# Nearest to pope: gregory, daisuke, papacy, sixtus, antipope, lateran, kinross, bolden,
# Nearest to question: answer, whether, memoirs, augsburg, visegr, genitive, cliffe, eulogies,
# Nearest to mainly: and, regained, many, bahamut, manco, in, morphological, dispenses,
# Nearest to institute: education, phoned, berklee, technology, inspection, dieter, laodicea, cleveland,
# Nearest to animals: footed, interbreeding, dogs, asparagales, canids, antennae, mesoplodon, herbivorous,
# Nearest to arts: martial, muay, thai, gallery, examinations, jitsu, intricate, academies,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8509 0.0304 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8550 0.0293 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8187 0.0294 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8237 0.0293 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8819 0.0295 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8348 0.0294 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9584 0.0293 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8832 0.0294 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8942 0.0293 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8173 0.0295 sec/batch
# Nearest to was: had, by, became, were, later, as, in, its,
# Nearest to no: comoros, would, abdicated, waste, one, that, crude, blyth,
# Nearest to which: in, by, a, and, of, such, the, original,
# Nearest to states: united, u, politicians, confederacy, perdido, shawnee, qatar, turkmenistan,
# Nearest to up: yearning, changing, slipped, stand, keep, steady, drysdale, franks,
# Nearest to a: as, of, and, for, in, the, by, is,
# Nearest to united: states, kingdom, ratify, kaiserliche, russia, morley, curtail, origin,
# Nearest to years: year, five, male, female, four, migrant, last, expectancy,
# Nearest to mean: steinsaltz, cocking, cubans, arithmetic, minima, hottest, wag, naturalisation,
# Nearest to placed: without, plated, scoring, gareth, drawn, carthusian, bandmates, nessus,
# Nearest to pope: gregory, sixtus, papacy, antipope, daisuke, kinross, lateran, krugman,
# Nearest to question: answer, whether, memoirs, augsburg, genitive, surfacing, visegr, sunscreen,
# Nearest to mainly: regained, many, bahamut, and, manco, experiences, ast, their,
# Nearest to institute: phoned, technology, education, berklee, inspection, cleveland, dieter, pais,
# Nearest to animals: footed, interbreeding, dogs, canids, asparagales, mesoplodon, herbivorous, antennae,
# Nearest to arts: martial, muay, thai, examinations, hingle, academies, jitsu, intricate,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7826 0.0303 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8706 0.0294 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8036 0.0296 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8799 0.0295 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8388 0.0294 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8415 0.0295 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9092 0.0172 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8199 0.0293 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8309 0.0294 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8547 0.0295 sec/batch
# Nearest to was: had, by, became, were, in, later, as, his,
# Nearest to no: comoros, would, abdicated, waste, englishmen, crude, caver, whereof,
# Nearest to which: by, in, a, and, is, of, such, the,
# Nearest to states: united, u, confederacy, politicians, perdido, shawnee, bales, territory,
# Nearest to up: yearning, changing, slipped, drysdale, fates, pours, stand, ccta,
# Nearest to a: as, of, and, the, in, for, by, is,
# Nearest to united: states, kingdom, ratify, morley, kaiserliche, glen, declares, invades,
# Nearest to years: year, migrant, five, female, male, four, births, expectancy,
# Nearest to mean: arithmetic, average, averages, steinsaltz, cocking, minima, cubans, lasts,
# Nearest to placed: without, plated, scoring, carthusian, gareth, bandmates, drawn, ceilings,
# Nearest to pope: gregory, sixtus, papacy, daisuke, antipope, kinross, cai, lateran,
# Nearest to question: answer, whether, memoirs, visegr, augsburg, sunscreen, informed, surfacing,
# Nearest to mainly: many, regained, their, ast, bahamut, experiences, main, manco,
# Nearest to institute: phoned, technology, berklee, education, cleveland, inspection, laodicea, dieter,
# Nearest to animals: asparagales, footed, interbreeding, dogs, mesoplodon, canids, herbivorous, taxonomists,
# Nearest to arts: martial, muay, examinations, thai, academies, intricate, jitsu, visualization,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8125 0.0304 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8210 0.0295 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8314 0.0293 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7984 0.0295 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8646 0.0293 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8128 0.0294 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8670 0.0294 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7442 0.0294 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7995 0.0293 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7804 0.0293 sec/batch
# Nearest to was: had, became, by, were, later, originally, in, first,
# Nearest to no: would, that, comoros, one, be, crude, waste, abdicated,
# Nearest to which: a, is, in, by, of, and, the, such,
# Nearest to states: united, u, perdido, qatar, politicians, confederacy, shawnee, territory,
# Nearest to up: yearning, them, changing, slipped, drysdale, stand, which, keep,
# Nearest to a: as, of, the, for, in, is, and, by,
# Nearest to united: states, kingdom, russia, naturalization, origin, ratify, kaiserliche, dumnonii,
# Nearest to years: male, female, five, four, migrant, year, births, expectancy,
# Nearest to mean: arithmetic, average, cocking, averages, steinsaltz, hottest, wag, cubans,
# Nearest to placed: without, plated, scoring, carthusian, gareth, zadok, ceilings, drawn,
# Nearest to pope: gregory, papacy, sixtus, daisuke, antipope, lateran, cai, kinross,
# Nearest to question: answer, whether, memoirs, augsburg, nonlinear, surfacing, cliffe, sunscreen,
# Nearest to mainly: many, regained, and, their, ast, manco, bahamut, experiences,
# Nearest to institute: phoned, education, berklee, inspection, technology, cleveland, laodicea, focuses,
# Nearest to animals: asparagales, interbreeding, herbivorous, canids, mesoplodon, footed, dogs, contractile,
# Nearest to arts: martial, examinations, muay, thai, academies, licensure, intricate, jitsu,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7687 0.0304 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8283 0.0293 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8549 0.0294 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8698 0.0294 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8182 0.0293 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9087 0.0294 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8577 0.0295 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8130 0.0293 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8131 0.0293 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8318 0.0293 sec/batch
# Nearest to was: had, by, became, later, were, in, originally, first,
# Nearest to no: comoros, would, abdicated, one, waste, that, englishmen, only,
# Nearest to which: in, a, by, is, of, the, and, such,
# Nearest to states: united, u, politicians, warranties, perdido, confederacy, qatar, principles,
# Nearest to up: yearning, keep, them, changing, stand, drysdale, nuova, slipped,
# Nearest to a: as, in, the, for, and, of, by, is,
# Nearest to united: states, kingdom, kaiserliche, origin, russia, morley, ratify, vermont,
# Nearest to years: five, female, male, four, year, migrant, last, births,
# Nearest to mean: arithmetic, steinsaltz, wag, cubans, hottest, cocking, newsweek, averages,
# Nearest to placed: without, plated, gareth, scoring, bandmates, zadok, carthusian, ceilings,
# Nearest to pope: gregory, papacy, sixtus, daisuke, lateran, antipope, cai, kinross,
# Nearest to question: answer, whether, memoirs, augsburg, nonlinear, cliffe, surfacing, eulogies,
# Nearest to mainly: regained, many, their, and, manco, bahamut, ast, tupi,
# Nearest to institute: education, phoned, technology, inspection, berklee, juilliard, cleveland, laodicea,
# Nearest to animals: interbreeding, asparagales, herbivorous, mesoplodon, dogs, footed, canids, pseudomonas,
# Nearest to arts: martial, examinations, muay, academies, thai, gallery, licensure, intricate,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8813 0.0304 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8646 0.0294 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7916 0.0294 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8438 0.0293 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8661 0.0293 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8294 0.0295 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8276 0.0294 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8262 0.0294 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8406 0.0293 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8261 0.0293 sec/batch
# Nearest to was: had, by, became, were, later, originally, in, first,
# Nearest to no: that, would, comoros, abdicated, only, waste, be, one,
# Nearest to which: in, by, of, a, and, the, is, with,
# Nearest to states: united, u, politicians, perdido, shawnee, warranties, confederacy, state,
# Nearest to up: yearning, them, keep, changing, into, stand, drysdale, allocations,
# Nearest to a: as, in, of, for, and, the, by, is,
# Nearest to united: states, kingdom, kaiserliche, russia, naturalization, ratify, countries, immigration,
# Nearest to years: five, four, year, male, female, migrant, zero, last,
# Nearest to mean: arithmetic, average, cocking, hottest, averages, cubans, steinsaltz, storm,
# Nearest to placed: without, plated, scoring, zadok, gareth, carthusian, bandmates, ceilings,
# Nearest to pope: gregory, papacy, sixtus, daisuke, lateran, antipope, kinross, bolden,
# Nearest to question: answer, whether, memoirs, augsburg, eulogies, surfacing, genitive, nonlinear,
# Nearest to mainly: regained, many, and, their, bahamut, main, manco, experiences,
# Nearest to institute: phoned, education, technology, berklee, inspection, laodicea, juilliard, cleveland,
# Nearest to animals: interbreeding, dogs, herbivorous, asparagales, mesoplodon, canids, antennae, footed,
# Nearest to arts: martial, muay, examinations, gallery, thai, licensure, academies, hingle,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8664 0.0304 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8155 0.0295 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9258 0.0296 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9097 0.0295 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8573 0.0292 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8426 0.0294 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7636 0.0294 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8624 0.0293 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7378 0.0295 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8840 0.0295 sec/batch
# Nearest to was: had, by, became, were, in, originally, later, as,
# Nearest to no: comoros, would, abdicated, crude, englishmen, schmitt, only, waste,
# Nearest to which: by, in, and, a, of, the, is, such,
# Nearest to states: united, u, perdido, shawnee, politicians, bales, state, confederacy,
# Nearest to up: yearning, them, changing, keep, drysdale, into, which, stand,
# Nearest to a: as, for, in, of, by, and, the, is,
# Nearest to united: states, kingdom, kaiserliche, spee, russia, declares, morley, ratify,
# Nearest to years: male, female, five, migrant, year, four, zero, birth,
# Nearest to mean: arithmetic, hottest, average, minima, cocking, averages, wag, commandment,
# Nearest to placed: without, plated, gareth, scoring, zadok, carthusian, bandmates, ceilings,
# Nearest to pope: gregory, papacy, sixtus, daisuke, antipope, lateran, bolden, cai,
# Nearest to question: answer, whether, memoirs, augsburg, surfacing, genitive, eulogies, nonlinear,
# Nearest to mainly: many, regained, their, bahamut, main, and, experiences, started,
# Nearest to institute: phoned, technology, inspection, education, berklee, pais, cleveland, laodicea,
# Nearest to animals: interbreeding, asparagales, dogs, herbivorous, mesoplodon, footed, canids, gargantuan,
# Nearest to arts: martial, muay, thai, jitsu, examinations, budo, capoeira, techniques,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8535 0.0305 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8555 0.0294 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
